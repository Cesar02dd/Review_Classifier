# %% [markdown]
# # Problem Statement
#
# A experiência do hóspede durante a sua estadia é influenciada por diversos fatores, como os serviços prestados, a limpeza, o atendimento e a alimentação. Estes fatores influenciam a avaliação do cliente e a sua probabilidade de regressar ao mesmo hotel.
#
# Compreender a emoção subjacente às avaliações de hotéis é essencial, pois proporciona insights valiosos sobre o que motiva os clientes a atribuir uma determinada avaliação. Muitas vezes, a avaliação numérica não reflete de forma adequada o valor expresso no comentário deixado pelo cliente.
#
# Identificar padrões nas avaliações e estabelecer um objetivo permitem à entidade hoteleira ter uma compreensão mais precisa dos problemas enfrentados na hospedagem de um cliente, possibilitando investimentos nessas áreas para proporcionar um retorno financeiro mais significativo. O objetivo, em suma, é aprimorar a experiência do cliente, aumentar a fidelidade à marca e assegurar o sucesso do hotel.
#
# ## Objective:
#
# O objetivo deste projeto é compreender as emoções dos clientes por trás das avaliações, identificar tendências nessas avaliações através da análise de dados e técnicas de processamento de linguagem natural, bem como atribuir uma classificação sentimental objetiva de forma automática a futuras avaliações.
#
# ## Approach:
#
# 1. **Data Loading**: Efetuar o carregamento inicial dos dados a serem utilizados no projeto, garantindo a obtenção correta das informações necessárias para as análises subsequentes.
#
# 2. **Data Pre Visualization**: Realizar uma análise inicial dos dados para compreender a sua estrutura e características fundamentais antes de iniciar o processo de modelagem.
#
# 3. **Data Preprocessing**: Realizar etapas abrangentes de pré-processamento de dados, incluindo o tratamento de valores em falta, a codificação de variáveis categóricas e a escala de características numéricas, a fim de preparar o conjunto de dados para o treino do modelo.
#
# 4. **Model Selection**: Explorar vários algoritmos de aprendizagem de máquina adequados para tarefas de classificação multiclasse, como árvores de decisão, florestas aleatórias, máquinas de vetores de suporte e redes neurais. Avaliar o desempenho de diferentes modelos utilizando métricas de avaliação apropriadas e técnicas de validação cruzada.
#
# 5. **Feature Engineering**: Experimentar com técnicas de engenharia de características para extrair insights significativos das características ambientais e melhorar o poder preditivo do modelo. Isso pode envolver a criação de novas características, a transformação de características existentes ou a seleção de subconjuntos de características com base na sua importância.
#
# 6. **Model Training and Evaluation**: Treinar o modelo de aprendizagem de máquina selecionado no conjunto de dados pré-processado e avaliar o seu desempenho utilizando conjuntos de validação ou métodos de validação cruzada. Ajustar hiperparâmetros para otimizar o desempenho do modelo e generalizar bem para dados não vistos.
#
# 7. **Interpretation and Insights**:  Interpretar o modelo treinado para compreender como diferentes características ambientais contribuem para a previsão dos tipos de cobertura florestal. Extrair insights das previsões do modelo para informar decisões de gestão florestal, estratégias de conservação e esforços de planeamento do uso da terra.
#
# ## Success Criteria:
#
# O sucesso do modelo preditivo será avaliado com base na sua capacidade de classificar com precisão os sentimentos das avaliações em categorias de "bom", "mau" e "neutro". Métricas-chave de desempenho, como precisão, precisão positiva, recall e pontuação F1, serão utilizadas para avaliar o desempenho do modelo em comparação com referências de linha de base e requisitos específicos do domínio.
#
# Ao abordar esses objetivos e seguir uma abordagem sistemática no desenvolvimento e avaliação do modelo, o objetivo é construir um modelo preditivo confiável e interpretável que possa contribuir para uma análise precisa e abrangente de sentimentos em textos. Isso terá aplicações significativas em diversas áreas, como análise de feedback do cliente, monitoramento de mídia social e tomada de decisões empresariais baseadas em sentimentos.

# %% [markdown]
# # Real World/Business Objectives and Constraints
#
# ## Objectives:
#
# 1. Desenvolver um modelo preditivo preciso e confiável para a análise de sentimentos em textos, classificando-os nas categorias de "bom", "mau" e "neutro".
#
# 2. Contribuir para uma compreensão abrangente e precisa dos sentimentos expressos em textos, fornecendo insights valiosos para áreas como feedback do cliente, monitoramento de mídia social e tomada de decisões empresariais baseadas em sentimentos.
#
# 3. Desenvolver um modelo interpretável que permita uma compreensão clara dos fatores que influenciam as classificações de sentimentos.
#
# ## Constraints:
#
# 1. Limitação de recursos computacionais para o treinamento e avaliação do modelo.
#
# 2. Tempo limitado para o desenvolvimento e implementação do modelo, exigindo eficiência no processo de projeto.
#
# 3. Os dados esão apenas em Inglês, impedindoa analise de texto em outros idiomas.
#
# Ao abordar estes objetivos e restrições, o modelo preditivo visa contribuir para uma análise de sentimentos precisa e abrangente, classificando textos nas categorias de "bom", "mau" e "neutro". Este esforço pretende fornecer insights valiosos para diversas aplicações, incluindo feedback do cliente, monitoramento de mídia social e apoio à tomada de decisões baseadas em sentimentos. O objetivo último é melhorar a compreensão dos sentimentos expressos nos textos, possibilitando uma análise mais refinada e informada das emoções presentes.

# %% [markdown]
# # Data Description
#
# O conjunto de dados contém diferentes características das reviews e o target irá ser o "Reviewer_Score" que a seguir será divido em Bins, que representa a classificação (Bom, Neutral ou Mau) da avaliação . As colunas disponiveis são as seguintes:
#
# - **Hotel_Address**: Endereço do hotel.
# - **Review_Date**: Data em que o revisor publicou a respetiva análise.
# - **Average_Score**: Pontuação média do hotel, calculada com base no comentário mais recente no último ano.
# - **Country_Name**: Pís do hotel.
# - **Hotel_Name**: Nome do hotel.
# - **Reviewer_Nationality**: Nacionalidade do revisor.
# - **Negative_Review**: Análise negativa atribuída pelo revisor ao hotel. Se o revisor não fornecer uma análise negativa, será registrado como: 'Sem Negativo'.
# - **Review_Total_Negative_Word_Counts**: Contagem total de palavras na análise negativa.
# - **Positive_Review**: Análise positiva atribuída pelo revisor ao hotel. Se o revisor não fornecer uma análise positiva, será registrado como: 'Sem Positivo'.
# - **Review_Total_Positive_Word_Counts**: Contagem total de palavras na análise positiva.
# - **Reviewer_Score**: Pontuação atribuída pelo revisor ao hotel, com base na sua experiência.
# - **Total_Number_of_Reviews_Reviewer_Has_Given**:  Número total de análises que o revisor fez no passado.
# - **Total_Number_of_Reviews**: Número total de análises válidas que o hotel recebeu.
# - **Tags**:  Tags atribuídas pelo revisor ao hotel.
# - **days_since_review**:  Período entre a data da análise e a data de extração.
# - **Additional_Number_of_Scoring**:  Existem também alguns hóspedes que apenas forneceram uma pontuação ao serviço, em vez de uma análise. Este número indica quantas pontuações válidas sem análise existem.
# - **lat**:  Latitude do hotel.
# - **lng**:  Longitude do hotel.

# %%
# Libraries

import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from nltk.corpus import stopwords
from wordcloud import WordCloud
from collections import Counter
import re
import numpy as np
import pandas as pd
import seaborn as sns
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
import umap
from mrmr import mrmr_classif
from matplotlib import pyplot as plt, cm
from matplotlib.colors import Normalize
from matplotlib.lines import Line2D
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import mutual_info_classif
from sklearn.manifold import LocallyLinearEmbedding, TSNE
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Data Analysis
# ## Pre Visualization

# %%
class DataLoader:

    def __init__(self, filepath, test_size=0.2, state=None):

        self.filepath = filepath
        self.test_size = test_size
        self.state = state

        self.dataframe = None
        self.data = None
        self.labels = None
        self.data_train = None
        self.labels_train = None
        self.data_test = None
        self.labels_test = None

        # Load Data
        self._load_data()

    def _load_data(self):
        try:
            # Ignore
            warnings.simplefilter(action='ignore', category=FutureWarning)

            # Load the Dataset
            df = pd.read_csv(self.filepath)
            self.dataframe = df

            # Split the data into features and labels
            self.data = df.drop(columns=['Reviewer_Score'])
            #self.target = df[['Reviewer_Score']]
            self.labels = df[['Reviewer_Score']].copy()

            self._encode_score()

            # Split the data into training and testing sets
            X_train, X_test, y_train, y_test = train_test_split(self.data, self.labels, test_size=self.test_size,
                                                                random_state=self.state)

            # Assign the data and labels to attributes
            self.data_train = X_train
            self.labels_train = y_train
            self.data_test = X_test
            self.labels_test = y_test

            print("Data loaded successfully.")

        except FileNotFoundError as e:
            print("File not found. Please check the file path.")

    def _encode_score(self):
        try:
            # Select Reviewer Score column
            feature_to_bin = 'Reviewer_Score'

            # Define the number of bins (or bin edges)
            bins_reviewer_score = [0, 4, 7, 10]

            # Perform binning using pandas
            self.labels['Reviewer_Score_bin'] = pd.cut(self.labels[feature_to_bin], bins=bins_reviewer_score,
                                                        labels=['Mau', 'Neutral', 'Bom'])

            # Create an instance of LabelEncoder
            label_encoder = LabelEncoder()

            # Encode the 'reviewer_score_bin' column
            self.labels['Reviewer_Score_bin_encoded'] = label_encoder.fit_transform(
                self.labels['Reviewer_Score_bin'])

            # Display the dataset after binning
            print('Dataset after binning score reviewer: \n', self.labels[['Reviewer_Score', 'Reviewer_Score_bin', 'Reviewer_Score_bin_encoded']])

            self.labels = self.labels['Reviewer_Score_bin_encoded']

            # Choose the  column for binning
            feature_to_bin2 = 'Total_Number_of_Reviews_Reviewer_Has_Given'
            feature_to_bin3 = 'Total_Number_of_Reviews'

            # Define the number of bins (or bin edges)
            bins_expertise_level = [0, 5, 10, 15, 20, float('inf')]
            bins_total_reviews = [0, 2500, 5000, 7500, float('inf')]

            # Perform binning using pandas

            reviewer_expertise_level_bin = pd.cut(self.data[feature_to_bin2],
                                                  bins=bins_expertise_level,
                                                  labels=['Nenhum', 'Baixo', 'Medio', 'Alto', 'Experto'])
            review_count_per_hotel_bin = pd.cut(self.data[feature_to_bin3], bins=bins_total_reviews,
                                                labels=['Poucas_Avaliações', 'Algumas_Avaliações',
                                                        'Muitas_Avaliações', 'Muitissimas_Avaliações'])

            label_encoder = LabelEncoder()
            label_encoder2 = LabelEncoder()

            # Encode the 'reviewer_score_bin' column
            self.data['Reviewer_Expertise_Level_Encoded'] = label_encoder.fit_transform(
                reviewer_expertise_level_bin)

            self.data['Review_Count_Per_Hotel_Encoded'] = label_encoder2.fit_transform(
                review_count_per_hotel_bin)

            # Display the dataset after binning
            print('Dataset after binning expertise level: \n',
                  self.data[
                      ['Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Expertise_Level_Encoded']].head(20))
            print('Dataset after binning expertise level: \n',
                  self.data[['Total_Number_of_Reviews', 'Review_Count_Per_Hotel_Encoded']])

            self.data = self.data.drop(columns=['Total_Number_of_Reviews_Reviewer_Has_Given', 'Total_Number_of_Reviews'])

        except Exception as e:
            print("Error:", e)

# %%
class DataManipulator(DataLoader):
    def __init__(self, filepath, test_size=0.2, state=None):
        super().__init__(filepath, test_size, state)

        # Manipulate data
        self.drop_columns()

    def drop_columns(self):
        try:
            # self.dataframe = self.dataframe.drop(columns=['Id_Hotel_Rating', 'Additional_Number_of_Scoring'])
            self.data = self.data.drop(columns=['Id_Hotel_Rating', 'Additional_Number_of_Scoring'])
            self.data_test = self.data_test.drop(columns=['Id_Hotel_Rating', 'Additional_Number_of_Scoring'])
            self.data_train = self.data_train.drop(columns=['Id_Hotel_Rating', 'Additional_Number_of_Scoring'])

        except Exception as e:
            print("Error:", e)

# %%
class DataPreprocessing:
    def __init__(self, data_loader):
        self.data_loader = data_loader

        # Preprocess data
        self._normalize_features()

    def _normalize_features(self):
        try:
            # Check if data_train and data_test are not None
            if self.data_loader.data_train is None or self.data_loader.data_test is None:
                raise ValueError("Data has not been loaded yet.")
            # Check if labels_train and labels_test are not None
            if self.data_loader.labels_train is None or self.data_loader.labels_test is None:
                raise ValueError("Labels have not been loaded yet.")

            # Select numeric columns
            numerical_columns = self.data_loader.data_train.select_dtypes(include=['number'])

            print("Numeric columns: " + numerical_columns.columns)

            # Select numeric features
            numerical_features = list(numerical_columns.columns)

            # Normalize real numeric features using StandardScaler
            scaler = StandardScaler()
            #self.data_loader.data[numerical_features] = scaler.fit_transform(
                #self.data_loader.data[numerical_features])
            self.data_loader.data_train[numerical_features] = scaler.fit_transform(
                self.data_loader.data_train[numerical_features])
            self.data_loader.data_test[numerical_features] = scaler.transform(
                self.data_loader.data_test[numerical_features])

            # # Identify encoded features
            # encoded_features = self.data_loader.data.columns[numerical_features]
            #
            # # Normalize encoded features using MinMaxScaler
            # scaler = MinMaxScaler()
            # self.data_loader.data[encoded_features] = scaler.fit_transform(
            #     self.data_loader.data[encoded_features])
            # self.data_loader.data_train[encoded_features] = scaler.fit_transform(
            #     self.data_loader.data_train[encoded_features])
            # self.data_loader.data_test[encoded_features] = scaler.transform(
            #     self.data_loader.data_test[encoded_features])

            print("Features normalized successfully.")

        except ValueError as ve:
            print("Error:", ve)

# %%
data_loader = DataManipulator("Hotel_Reviews.csv")
data_preprocessing = DataPreprocessing(data_loader)
# Out:
# Dataset after binning score reviewer:
#          Reviewer_Score Reviewer_Score_bin  Reviewer_Score_bin_encoded
# 0                  2.9                Mau                           1
# 1                  7.5                Bom                           0
# 2                  7.1                Bom                           0
# 3                  3.8                Mau                           1
# 4                  6.7            Neutral                           2
# ...                ...                ...                         ...
# 515733             7.0            Neutral                           2
# 515734             5.8            Neutral                           2
# 515735             2.5                Mau                           1
# 515736             8.8                Bom                           0
# 515737             8.3                Bom                           0
#
# [515738 rows x 3 columns]
# Dataset after binning expertise level:
#      Total_Number_of_Reviews_Reviewer_Has_Given  \
# 0                                            7
# 1                                            7
# 2                                            9
# 3                                            1
# 4                                            3
# 5                                            1
# 6                                            6
# 7                                            1
# 8                                            3
# 9                                            1
# 10                                           2
# 11                                          12
# 12                                           7
# 13                                           6
# 14                                           1
# 15                                          26
# 16                                           8
# 17                                           2
# 18                                           4
# 19                                          16
#
#     Reviewer_Expertise_Level_Encoded
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  4
# 4                                  4
# 5                                  4
# 6                                  1
# 7                                  4
# 8                                  4
# 9                                  4
# 10                                 4
# 11                                 3
# 12                                 1
# 13                                 1
# 14                                 4
# 15                                 2
# 16                                 1
# 17                                 4
# 18                                 4
# 19                                 0
# Dataset after binning expertise level:
#          Total_Number_of_Reviews  Review_Count_Per_Hotel_Encoded
# 0                          1403                               3
# 1                          1403                               3
# 2                          1403                               3
# 3                          1403                               3
# 4                          1403                               3
# ...                         ...                             ...
# 515733                     2823                               0
# 515734                     2823                               0
# 515735                     2823                               0
# 515736                     2823                               0
# 515737                     2823                               0
#
# [515738 rows x 2 columns]
# Data loaded successfully.
# Index(['Numeric columns: Average_Score',
#        'Numeric columns: Review_Total_Negative_Word_Counts',
#        'Numeric columns: Review_Total_Positive_Word_Counts',
#        'Numeric columns: lat', 'Numeric columns: lng',
#        'Numeric columns: Reviewer_Expertise_Level_Encoded',
#        'Numeric columns: Review_Count_Per_Hotel_Encoded'],
#       dtype='object')
# Features normalized successfully.

# %%
class PreVisualization:
    def __init__(self, data_loader):
        self.data_loader = data_loader
        self.data_loader.dataframe.dropna(inplace=True)

    def perform_pre_visualization(self):
        self.numpy_statistics()

        self.create_plots()

    def numpy_statistics(self):
        # Select numerical columns
        numerical_columns = self.data_loader.dataframe.select_dtypes(include=['number'])
        print(numerical_columns.columns)

        arr = numerical_columns.iloc[:, 2:].to_numpy()
        #print(np.mean(arr[:, 6]))

        print("\nSummary Statistics with NumPy:")

        # Mean
        print("\n*  Mean  *")
        print("Average_Score:", np.round(np.mean(arr[:, 0]), 2))
        print("Review_Total_Negative_Word_Counts:", np.round(np.mean(arr[:, 1]), 2))
        print("Total_Number_of_Reviews:", np.round(np.mean(arr[:, 2]), 2))
        print("Review_Total_Positive_Word_Counts:", np.round(np.mean(arr[:, 3]), 2))
        print("Total_Number_of_Reviews_Reviewer_Has_Given:", np.round(np.mean(arr[:, 4]), 2))
        print("Reviewer_Score:", np.round(np.mean(arr[:, 5]), 2))
        print("lat:", np.round(np.mean(arr[:, 6]), 2))
        print("lng:", np.round(np.mean(arr[:, 7]), 2))

        # Median
        print("\n*  Median  *")
        print("Average_Score:", np.round(np.median(arr[:, 0]), 2))
        print("Review_Total_Negative_Word_Counts:", np.round(np.median(arr[:, 1]), 2))
        print("Total_Number_of_Reviews:", np.round(np.median(arr[:, 2]), 2))
        print("Review_Total_Positive_Word_Counts:", np.round(np.median(arr[:, 3]), 2))
        print("Total_Number_of_Reviews_Reviewer_Has_Given:", np.round(np.median(arr[:, 4]), 2))
        print("Reviewer_Score:", np.round(np.median(arr[:, 5]), 2))
        print("lat:", np.round(np.median(arr[:, 6]), 2))
        print("lng:", np.round(np.median(arr[:, 7]), 2))

        # Standard Deviation
        print("\n*  Standard Deviation  *")
        print("Average_Score:", np.round(np.std(arr[:, 0]), 2))
        print("Review_Total_Negative_Word_Counts:", np.round(np.std(arr[:, 1]), 2))
        print("Total_Number_of_Reviews:", np.round(np.std(arr[:, 2]), 2))
        print("Review_Total_Positive_Word_Counts:", np.round(np.std(arr[:, 3]), 2))
        print("Total_Number_of_Reviews_Reviewer_Has_Given:", np.round(np.std(arr[:, 4]), 2))
        print("Reviewer_Score:", np.round(np.std(arr[:, 5]), 2))
        print("lat:", np.round(np.std(arr[:, 6]), 2))
        print("lng:", np.round(np.std(arr[:, 7]), 2))

    def create_plots(self):

        # Histograma entre o Num de Reviews e o Score
        plt.figure(figsize=(9, 7))
        plt.hist(self.data_loader.dataframe["Reviewer_Score"])
        plt.xlim(2.5, 10)
        plt.xlabel("Score")
        plt.ylabel("Numb of Reviews")
        plt.title("Score Distribution")
        plt.savefig('score_distribution.png', dpi=300, bbox_inches='tight')
        plt.show()

        '''
        plt.figure(figsize=(9, 7), facecolor='black')  # Define o fundo da figura como preto
        plt.hist(hotel_reviews["Reviewer_Score"], color='red')  # Define a cor do histograma como vermelho
        plt.xlim(2, 10)
        plt.xlabel("Score", color='white')  # Define a cor do texto do eixo x como branco
        plt.ylabel("Numb of Reviews", color='white')  # Define a cor do texto do eixo y como branco
        plt.title("Score Distribution", color='white')  # Define a cor do título como branco
        plt.gca().spines['bottom'].set_color('white')  # Define a cor da linha do eixo x como branco
        plt.gca().spines['left'].set_color('white')  # Define a cor da linha do eixo y como branco
        plt.tick_params(axis='x', colors='white')  # Define a cor dos números do eixo x como branco
        plt.tick_params(axis='y', colors='white')  # Define a cor dos números do eixo y como branco
        plt.savefig('score_distribution2.png', dpi=300, bbox_inches='tight')
        plt.show()
        '''

        # Densidade do Kernel entre o Num de Reviews e o Score
        plt.figure(figsize=(9, 9))
        sns.displot(self.data_loader.dataframe["Reviewer_Score"], kind="kde")
        plt.xlim(2, 10)
        plt.xlabel("Score")
        plt.ylabel("Numb of Reviews")
        plt.title("Kernel Density - Score Distribution")
        plt.savefig('score_distribution_kde.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Scatterplot - Relação entre número de reviews feitas e pontuação dada ao hotel
        plt.figure(figsize=(9, 7))
        sns.scatterplot(x="Total_Number_of_Reviews_Reviewer_Has_Given", y="Reviewer_Score", data=self.data_loader.dataframe,
                        alpha=0.5, s=30)
        plt.xlabel("Number of Reviews made")
        plt.ylabel("Score")
        plt.title("Relationship between number of reviews made and score given to the hotel")
        plt.savefig('Scatterplot.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Calcular a média de pontuação para cada país
        pontuacao_media_por_pais = self.data_loader.dataframe.groupby('Country_Name')['Reviewer_Score'].mean()

        # Criar o gráfico de barras
        plt.figure(figsize=(10, 6))
        pontuacao_media_por_pais.plot(kind='bar', color='skyblue')

        # Adicionar rótulos e título
        plt.xlabel('Country')
        plt.ylabel('Average Hotel Score')
        plt.title('Average Hotel Score by Country')

        # Adicionar as médias como anotações nas barras
        for i, pontuacao in enumerate(pontuacao_media_por_pais):
            plt.text(i, pontuacao, f'{pontuacao:.2f}', ha='center', va='bottom')

        plt.xticks(rotation=45, ha='right')
        plt.grid(axis='y')
        plt.tight_layout()
        plt.savefig('average_scores_by_country.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Quantidade Paises representados (Hoteis)
        pessoas_por_pais = self.data_loader.dataframe['Country_Name'].value_counts()

        # Criar o gráfico de pizza
        plt.figure(figsize=(10, 6))
        plt.pie(pessoas_por_pais, labels=pessoas_por_pais.index, autopct='%1.1f%%', startangle=140)
        plt.title('Amount of data per country')
        plt.axis('equal')
        plt.savefig('amount_data_per_country.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Criar o heatmap
        plt.figure(figsize=(12, 6))
        sns.heatmap(
            self.data_loader.dataframe.pivot_table(index='Country_Name', columns='Reviewer_Score', values='Average_Score'),
            cmap='coolwarm')
        plt.xlabel('Reviewer_Score')
        plt.ylabel('Country_Name')
        plt.title('Heatmap da Pontuação Média do Hotel por País e Pontuação do Revisor')
        plt.show()

        # Criar o boxplot
        plt.figure(figsize=(12, 12))
        sns.boxplot(x='Country_Name', y='Reviewer_Score', data=self.data_loader.dataframe)
        plt.xlabel('Country_Name')
        plt.ylabel('Reviewer_Score')
        plt.title('Boxplot da Pontuação do Revisor por País')
        plt.xticks(rotation=45)
        plt.show()

        # Criar o violin plot
        plt.figure(figsize=(7, 5))
        sns.violinplot(x='Country_Name', y='Reviewer_Score', data=self.data_loader.dataframe)
        plt.xlabel('País')
        plt.ylabel('Pontuação do Revisor')
        plt.title('Distribuição da Pontuação do Revisor por País')
        plt.xticks(rotation=45)
        plt.show()

        '''
        # Quantidade Paises representados (Reviewer_Nationality)
        pessoas_por_pais = hotel_reviews['Reviewer_Nationality'].value_counts()
        # Criar o gráfico de pizza
        plt.figure(figsize=(10, 6))
        plt.pie(pessoas_por_pais, labels=pessoas_por_pais.index, autopct='%1.1f%%', startangle=140)
        plt.title('Amount of data per country')
        plt.axis('equal')
        plt.savefig('amount_data_per_country.png', dpi=300, bbox_inches='tight')
        plt.show()
        '''

        # Heatmap da Pontuação Média por País
        plt.figure(figsize=(12, 7))
        sns.heatmap(
            self.data_loader.dataframe.pivot_table(index='Country_Name', columns='Reviewer_Score', values='Average_Score'),
            cmap='coolwarm')
        plt.xlabel('Review_Score')
        plt.ylabel('Country')
        plt.title('Average Score Heatmap by Country')
        plt.savefig('average_score_heatmap_country.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Boxplot do review score por país
        plt.figure(figsize=(12, 12))
        sns.boxplot(x='Country_Name', y='Reviewer_Score', data=self.data_loader.dataframe)
        plt.xlabel('Country')
        plt.ylabel('Reviewer_Score')
        plt.title('Boxplot of Reviewer Score by Country')
        plt.xticks(rotation=45)
        plt.savefig('Boxplot_Reviewer_Score_Country.png', dpi=300, bbox_inches='tight')
        plt.show()

        # violin plot - Distribuição da pontuação da review por país
        plt.figure(figsize=(7, 5))
        sns.violinplot(x='Country_Name', y='Reviewer_Score', data=self.data_loader.dataframe)
        plt.xlabel('Country')
        plt.ylabel('Reviewer_Score')
        plt.title('Reviewer Score Distribution by Country')
        plt.xticks(rotation=45)
        plt.savefig('reviewer_score_distribution_country_vp.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Definir as faixas de número de reviews
        review_ranges = [(0, 3), (4, 6), (7, 9), (10, 12), (13, 15), (16, 18), (19, 21), (21, 24), (25, float('inf'))]

        # Inicializar contadores para cada faixa
        count_per_range = [0] * len(review_ranges)

        # Contar o número de pessoas em cada faixa de reviews
        for i, (start, end) in enumerate(review_ranges):
            count_per_range[i] = \
            self.data_loader.dataframe[(self.data_loader.dataframe['Total_Number_of_Reviews_Reviewer_Has_Given'] >= start) &
                                  (self.data_loader.dataframe[
                                       'Total_Number_of_Reviews_Reviewer_Has_Given'] <= end)].shape[0]

        # Definir rótulos das faixas
        labels = [f'{start}-{end}' if end != float('inf') else f'{start}+' for start, end in review_ranges]

        # Plotar o gráfico de barras
        plt.figure(figsize=(10, 6))
        plt.bar(labels, count_per_range, color='skyblue')
        plt.title('Quantidade de Pessoas por Faixa de Número de Reviews Dados')
        plt.xlabel('Faixa de Número de Reviews')
        plt.ylabel('Quantidade de Pessoas')
        plt.grid(axis='y')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

    def plot_positive_negative_reviews(self):
        # Converte a coluna 'Review_Date' para o tipo datetime
        self.data_loader.dataframe['Review_Date'] = pd.to_datetime(self.data_loader.dataframe['Review_Date'])

        # Extrai o mês da data
        self.data_loader.dataframe['Month'] = self.data_loader.dataframe['Review_Date'].dt.month

        # Conta a quantidade de revisões por mês
        reviews_count_by_month = self.data_loader.dataframe.groupby('Month').size()

        # Cria o gráfico de barras
        plt.figure(figsize=(10, 6))
        plt.bar(reviews_count_by_month.index, reviews_count_by_month, color='skyblue')

        # Define rótulos nos eixos e um título
        plt.xlabel('Mês')
        plt.ylabel('Número de Revisões')
        plt.title('Número de Revisões por Mês')

        # Ajusta os ticks do eixo X e os limites do eixo X
        plt.xticks(range(1, 13),
                   ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro',
                    'Novembro', 'Dezembro'], rotation=45)
        plt.xlim(0.5, 12.5)  # Ajustar os limites do eixo X para que todas as barras sejam visíveis

        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

        # Calcula a média de palavras positivas para cada pontuação de revisão
        avg_positive_words = self.data_loader.dataframe.groupby('Reviewer_Score')['Review_Total_Positive_Word_Counts'].mean()

        # Cria o gráfico de barras
        plt.figure(figsize=(10, 6))
        avg_positive_words.plot(kind='bar', color='lightgreen')
        plt.xlabel('Pontuação do Revisor')
        plt.ylabel('Contagem Média de Palavras Positivas')
        plt.title('Contagem Média de Palavras Positivas por Pontuação do Revisor')
        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

        # Calcula a média de palavras negativas para cada pontuação de revisão
        avg_negative_words = self.data_loader.dataframe.groupby('Reviewer_Score')['Review_Total_Negative_Word_Counts'].mean()

        # Cria o gráfico de barras
        plt.figure(figsize=(10, 6))
        avg_negative_words.plot(kind='bar', color='salmon', alpha=0.7)
        plt.xlabel('Pontuação do Revisor')
        plt.ylabel('Contagem Média de Palavras Negativas')
        plt.title('Contagem Média de Palavras Negativas por Pontuação do Revisor')
        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

    def process_reviews(self, reviews_column):
        # Combina as reviews num unico texto
        all_reviews = ' '.join(reviews_column)

        # Tokeniza o texto em palavras, ignorando numeros e Case Sensitive
        words = re.findall(r'\b[A-Za-z]+\b', all_reviews.lower())

        # Filtra palavras comuns usando NLTK
        english_stopwords = set(stopwords.words('english'))
        filtered_words = [word for word in words if word not in english_stopwords]

        # Conta a frequência de cada palavra
        word_counts = Counter(filtered_words)

        # Obtem as 100 palavras mais comuns
        top_100_words = word_counts.most_common(100)

        # Converte a lista de tuplos num dicionario
        word_freq_dict = dict(top_100_words)

        # Cria um DataFrame para mostrar todas as palavras e a sua frequência
        df = pd.DataFrame(top_100_words, columns=['Palavra', 'Nº de Repetições'])

        return word_freq_dict, df

    def show_wordcloud(self, word_freq, title=None):
        wordcloud = WordCloud(
            background_color='white',
            max_words=200,
            max_font_size=40,
            scale=3,
            random_state=42
        )

        wordcloud.generate_from_frequencies(word_freq)

        plt.figure(figsize=(10, 6))
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis('off')
        if title:
            plt.title(title, fontsize=20)
        plt.show()

    def create_nice_wordcloud(self):

        # Filtra apenas as palavras de reviews positivas
        positive_reviews = self.data_loader.dataframe[self.data_loader.dataframe['Positive_Review'] != 'No Positive']
        word_freq_dict_pos, df_pos = self.process_reviews(positive_reviews['Positive_Review'])

        # Mostra a tabela de palavras mais repetidas en reviews positivas
        print("\nTabela de palavras mais repetidas em Reviews Positivas:\n")
        print(df_pos)

        # Mostra a nube de palavras nas reviews positivas
        self.show_wordcloud(word_freq_dict_pos, "Nuvem de Palavras Mais Comuns em Reviews Positivas")

        # Filtra apenas as palavras de reviews negativas
        negative_reviews = self.data_loader.dataframe[self.data_loader.dataframe['Negative_Review'] != 'No Negative']
        word_freq_dict_neg, df_neg = self.process_reviews(negative_reviews['Negative_Review'])

        # Mostra a tabela de palavras mais repetidas en reviews negativas
        print("\nTabela de palavras mais repetidas em Reviews Negativas:\n")
        print(df_neg)

        # Mostra a nube de palavras nas reviews negativas
        self.show_wordcloud(word_freq_dict_neg, "Nuvem de Palavras Mais Comuns em Reviews Negativas")

# %%
pre_visualization = PreVisualization(data_loader)
pre_visualization.perform_pre_visualization()
# Out:
# Index(['Id_Hotel_Rating', 'Additional_Number_of_Scoring', 'Average_Score',
#        'Review_Total_Negative_Word_Counts', 'Total_Number_of_Reviews',
#        'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score', 'lat',
#        'lng'],
#       dtype='object')
#
# Summary Statistics with NumPy:
#
# *  Mean  *
# Average_Score: 8.4
# Review_Total_Negative_Word_Counts: 18.54
# Total_Number_of_Reviews: 2747.5
# Review_Total_Positive_Word_Counts: 17.77
# Total_Number_of_Reviews_Reviewer_Has_Given: 7.15
# Reviewer_Score: 8.4
# lat: 49.44
# lng: 2.82
#
# *  Median  *
# Average_Score: 8.4
# Review_Total_Negative_Word_Counts: 9.0
# Total_Number_of_Reviews: 2134.0
# Review_Total_Positive_Word_Counts: 11.0
# Total_Number_of_Reviews_Reviewer_Has_Given: 3.0
# Reviewer_Score: 8.8
# lat: 51.5
# lng: 0.01
#
# *  Standard Deviation  *
# Average_Score: 0.55
# Review_Total_Negative_Word_Counts: 29.69
# Total_Number_of_Reviews: 2322.7
# Review_Total_Positive_Word_Counts: 21.79
# Total_Number_of_Reviews_Reviewer_Has_Given: 11.03
# Reviewer_Score: 1.64
# lat: 3.47
# lng: 4.58

# %%
class DataCleaning:
    def __init__(self, data_loader):
        self.data_loader = data_loader

    def remove_duplicates(self):
        try:
            # Check if data and labels are not None
            if self.data_loader.data_train is None:
                raise ValueError("Data has not been loaded yet.")
            if self.data_loader.labels_train is None:
                raise ValueError("Labels have not been loaded yet.")

            # Remove duplicate rows from training data (do not apply to test data)
            self.data_loader.data_train.drop_duplicates(inplace=True)
            self.data_loader.labels_train = self.data_loader.labels_train[self.data_loader.data_train.index]

            print("Duplicate rows removed from training data.")

        except ValueError as ve:
            print("Error:", ve)

    def handle_missing_values(self, strategy='drop'):
        try:
            # Check if data is not None
            if self.data_loader.data_train is None or self.data_loader.data_test is None:
                raise ValueError("Data has not been loaded yet.")

            # Check if there are missing values
            if self.data_loader.data_train.isnull().sum().sum() == 0 and self.data_loader.data_test.isnull().sum().sum() == 0:
                print("No missing values found in the data.")
                return

            # Handle missing values based on the specified strategy
            if strategy == 'mean':
                self.data_loader.data_train.fillna(self.data_loader.data_train.mean(), inplace=True)
                self.data_loader.data_test.fillna(self.data_loader.data_test.mean(), inplace=True)
            elif strategy == 'median':
                self.data_loader.data_train.fillna(self.data_loader.data_train.median(), inplace=True)
                self.data_loader.data_test.fillna(self.data_loader.data_test.median(), inplace=True)
            elif strategy == 'most_frequent':
                self.data_loader.data_train.fillna(self.data_loader.data_train.mode().iloc[0], inplace=True)
                self.data_loader.data_test.fillna(self.data_loader.data_test.mode().iloc[0], inplace=True)
            elif strategy == 'fill_nan':
                self.data_loader.data_train.fillna(strategy, inplace=True)
                self.data_loader.data_test.fillna(strategy, inplace=True)
            elif strategy == 'drop':
                self.data_loader.data_train = self.data_loader.data_train.dropna(axis=0)
                self.data_loader.labels_train = self.data_loader.labels_train[self.data_loader.data_train.index]
                self.data_loader.data_test = self.data_loader.data_test.dropna(axis=0)
                self.data_loader.labels_test = self.data_loader.labels_test[self.data_loader.data_test.index]

            else:
                raise ValueError("Invalid strategy.")
            print("Missing values handled using strategy:", strategy)

        except ValueError as ve:
            print("Error:", ve)

    def _detect_outliers(self):
        try:
            # Check if test data is not None
            if self.data_loader.data_train is None:
                raise ValueError("Data has not been loaded yet.")

            # Dealing with outliers for all numerical columns
            outliers = None

            print("\nDetecting outliers:")
            for feature in self.data_loader.data_train.select_dtypes(include=[np.number]).columns:
                # Calculate the IQR (InterQuartile Range)
                Q1 = self.data_loader.data_train[feature].quantile(0.25)
                Q3 = self.data_loader.data_train[feature].quantile(0.75)
                IQR = Q3 - Q1

                # Define the lower and upper bounds to identify outliers
                upper_bound = Q3 + 1.5 * IQR
                lower_bound = Q1 - 1.5 * IQR

                outliers = self.data_loader.data_train[
                    (self.data_loader.data_train[feature] < lower_bound) | (self.data_loader.data_train[feature] > upper_bound)]
                # Each row represents a data point where the values for the features are listed.
                # The first row presents the indices of the DataFrame where the outliers were detected.
                print(f"Outliers in '{feature}':\n{outliers}" if not outliers.empty else f"No outliers in '{feature}'.")

            # Display dataset after handling outliers for all numerical columns
            print(self.data_loader.data_train)

            return outliers

        except Exception as e:
            print("Error:", e)

    def remove_outliers(self):
        try:
            # Check if data_loader.data_train is not None
            if self.data_loader.data_train is None:
                raise ValueError("Data has not been loaded yet.")

            # Detect outliers
            outliers = self._detect_outliers()

            # Remove outliers from the dataset
            self.data_loader.data_train = self.data_loader.data_train.drop(outliers.index)
            self.data_loader.labels_train = self.data_loader.labels_train[self.data_loader.data_train.index]

            print("Outliers removed from the dataset.")

        except Exception as e:
            print("Error:", e)

# %%
# Access the data and labels attributes
print("\n\nBefore data preprocessing")
print("Normal data shape:", data_loader.data.shape)
print("Normal labels shape:", data_loader.labels.shape)
print("Training data shape:", data_loader.data_train.shape)
print("Training labels shape:", data_loader.labels_train.shape)
print("Testing data shape:", data_loader.data_test.shape)
print("Testing labels shape:", data_loader.labels_test.shape)

data_cleaner = DataCleaning(data_loader)
data_cleaner.remove_duplicates()
data_cleaner.handle_missing_values()
data_cleaner.remove_outliers()

print("\n\nAfter data preprocessing")
print("Training data shape:", data_loader.data_train.shape)
print("Training labels shape:", data_loader.labels_train.shape)
print("Testing data shape:", data_loader.data_test.shape)
print("Testing labels shape:", data_loader.labels_test.shape)

# Serialize data_loader object to save a copy of the cleaned data
with open('data_loader.pkl', 'wb') as f:
    pickle.dump(data_loader, f)

# Deserialize data_loader object to restore the cleaned data
with open('data_loader.pkl', 'rb') as f:
    data_loader_loaded = pickle.load(f)
print("\n\nDeserialized data")
print("Training data shape:", data_loader_loaded.data_train.shape)
print("Training labels shape:", data_loader_loaded.labels_train.shape)
print("Testing data shape:", data_loader_loaded.data_test.shape)
print("Testing labels shape:", data_loader_loaded.labels_test.shape)
# Out:
# Before data preprocessing
# Normal data shape: (515738, 17)
# Normal labels shape: (515738,)
# Training data shape: (412590, 17)
# Training labels shape: (412590,)
# Testing data shape: (103148, 17)
# Testing labels shape: (103148,)
# Duplicate rows removed from training data.
# Missing values handled using strategy: drop
#
# Detecting outliers:
# Outliers in 'Average_Score':
#                                             Hotel_Address Province_Name  \
# 498371      Vijzelstraat 4 Amsterdam City Center 1017 HK     Amsterdam
# 91916   2 Stanhope Row Park Lane Westminster Borough  ...        London
# 205212     50 Lancaster Gate Westminster Borough  W2 3NA         London
# 498001      Vijzelstraat 4 Amsterdam City Center 1017 HK     Amsterdam
# 131299               29 31 Gower Street Camden  WC1E 6HG         London
# ...                                                   ...           ...
# 115982   23 Leinster Gardens Westminster Borough  W2 3AN         London
# 242978                  75 Gower Street Camden  WC1E 6HJ         London
# 131003               29 31 Gower Street Camden  WC1E 6HG         London
# 242624                  75 Gower Street Camden  WC1E 6HJ         London
# 364745  Lancaster Terrace Hyde Park Westminster Boroug...        London
#
#           Country_Name Review_Date  Average_Score               Hotel_Name  \
# 498371     Netherlands    6/3/2016      -2.549802     NH Carlton Amsterdam
# 91916   United Kingdom   1/21/2016      -2.549802     Park Lane Mews Hotel
# 205212  United Kingdom   10/2/2015      -3.097135          Commodore Hotel
# 498001     Netherlands   7/23/2017      -2.549802     NH Carlton Amsterdam
# 131299  United Kingdom    2/6/2016      -2.914691  Bloomsbury Palace Hotel
# ...                ...         ...            ...                      ...
# 115982  United Kingdom   8/23/2016      -2.549802               Henry VIII
# 242978  United Kingdom   9/25/2016      -3.644468          Hotel Cavendish
# 131003  United Kingdom  12/21/2016      -2.914691  Bloomsbury Palace Hotel
# 242624  United Kingdom    5/6/2016      -3.644468          Hotel Cavendish
# 364745  United Kingdom  11/25/2015      -2.549802   London Elizabeth Hotel
#
#                           Reviewer_Nationality  \
# 498371   United States Minor Outlying Islands
# 91916                             Isle of Man
# 205212                         United Kingdom
# 498001                         United Kingdom
# 131299                               Portugal
# ...                                        ...
# 115982                         United Kingdom
# 242978                            Netherlands
# 131003                   United Arab Emirates
# 242624                         United Kingdom
# 364745                         United Kingdom
#
#                                           Negative_Review  \
# 498371                                   No pool swimming
# 91916    Got into a dirty bed full of stale breadcrumb...
# 205212   Torn carpet tiny bathroom very tired d cor no...
# 498001                                        No Negative
# 131299   I used to pay the hotel room charge when I ch...
# ...                                                   ...
# 115982                                        No Negative
# 242978           Old needs a lttle paint Very small room
# 131003   I booked a small single room but this is an e...
# 242624   The mattress was very saggy but pillows were ...
# 364745                            noisy limited breakfast
#
#         Review_Total_Negative_Word_Counts  \
# 498371                          -0.489078
# 91916                            2.199296
# 205212                           0.283830
# 498001                          -0.623496
# 131299                           0.519062
# ...                                   ...
# 115982                          -0.623496
# 242978                          -0.287450
# 131003                           1.090342
# 242624                           0.855109
# 364745                          -0.489078
#
#                                           Positive_Review  \
# 498371                                         Everything
# 91916                                            Location
# 205212                                          Location
# 498001   perfect location right in the heart of city c...
# 131299                       it is nearby British museum
# ...                                                   ...
# 115982   Like the High celling with celling fan Room n...
# 242978                                  Decent breakfast
# 131003   Location was great Small walk to oxford stree...
# 242624   Good location was what I was expecting for th...
# 364745                        Location style of the hotel
#
#         Review_Total_Positive_Word_Counts  \
# 498371                          -0.724184
# 91916                           -0.724184
# 205212                          -0.678324
# 498001                          -0.357306
# 131299                          -0.494885
# ...                                   ...
# 115982                           0.101292
# 242978                          -0.632465
# 131003                          -0.036287
# 242624                           1.156067
# 364745                          -0.540745
#
#                                                      Tags days_since_review  \
# 498371  [' Leisure trip ', ' Couple ', ' Standard Doub...           426 day
# 91916   [' Business trip ', ' Couple ', ' Double Room ...           560 day
# 205212  [' Business trip ', ' Solo traveler ', ' Doubl...           671 day
# 498001  [' Leisure trip ', ' Group ', ' Standard Doubl...           11 days
# 131299  [' Family with young children ', ' Double Room...           544 day
# ...                                                   ...               ...
# 115982  [' Leisure trip ', ' Family with young childre...           345 day
# 242978  [' Business trip ', ' Solo traveler ', ' Singl...           312 day
# 131003  [' Leisure trip ', ' Solo traveler ', ' Small ...           225 day
# 242624  [' Leisure trip ', ' Solo traveler ', ' Single...           454 day
# 364745  [' Leisure trip ', ' Group ', ' Twin Room ', '...           617 day
#
#              lat       lng  Reviewer_Expertise_Level_Encoded  \
# 498371  0.843551  0.450572                          0.671697
# 91916   0.595221 -0.649416                          0.671697
# 205212  0.597102 -0.656087                         -1.610055
# 498001  0.843551  0.450572                          0.671697
# 131299  0.599511 -0.645520                          0.671697
# ...          ...       ...                               ...
# 115982  0.597107 -0.656688                          0.671697
# 242978  0.599873 -0.645810                         -1.610055
# 131003  0.599511 -0.645520                          0.671697
# 242624  0.599873 -0.645810                          0.671697
# 364745  0.596979 -0.655372                         -1.610055
#
#         Review_Count_Per_Hotel_Encoded
# 498371                       -1.403862
# 91916                         0.805851
# 205212                        0.805851
# 498001                       -1.403862
# 131299                       -1.403862
# ...                                ...
# 115982                       -1.403862
# 242978                        0.805851
# 131003                       -1.403862
# 242624                        0.805851
# 364745                        0.805851
#
# [7592 rows x 17 columns]
# Outliers in 'Review_Total_Negative_Word_Counts':
#                                             Hotel_Address Province_Name  \
# 36193          112 boulevard de S bastopol 3rd arr 75003         Paris
# 234813           7 Gracechurch Street City of   EC3V 0DR         London
# 99627                     20 Rue Jean Rey 15th arr 75015         Paris
# 395805                Paral lel 115 Sants Montju c 08004     Barcelona
# 411211              Pintor Fortuny 13 Ciutat Vella 08001     Barcelona
# ...                                                   ...           ...
# 288501                    Boquer a 10 Ciutat Vella 08002     Barcelona
# 445710                    Schlossallee 8 14 Penzing 1140        Vienna
# 468211                  Ungargasse 60 03 Landstra e 1030        Vienna
# 11703             1 Kings Cross Road Islington  WC1X 9HX         London
# 140923  30 Leinster Gardens Bayswater Westminster Boro...        London
#
#           Country_Name Review_Date  Average_Score  \
# 36193           France   2/23/2016      -0.178025
# 234813  United Kingdom    6/5/2017      -0.360469
# 99627           France   6/20/2017      -0.725358
# 395805           Spain   3/14/2017      -0.360469
# 411211           Spain  10/29/2016      -0.907802
# ...                ...         ...            ...
# 288501           Spain    6/7/2016       0.186864
# 445710         Austria  12/29/2015       0.734197
# 468211         Austria    5/1/2017      -0.542913
# 11703   United Kingdom   2/18/2016      -0.542913
# 140923  United Kingdom   6/25/2017       0.186864
#
#                                              Hotel_Name  \
# 36193     Best Western Premier Marais Grands Boulevards
# 234813                  Club Quarters Hotel Gracechurch
# 99627                  Mercure Paris Centre Tour Eiffel
# 395805                                 Silken Concordia
# 411211                                   Silken Ramblas
# ...                                                 ...
# 288501                     Petit Palace Boqueria Garden
# 445710     Austria Trend Hotel Park Royal Palace Vienna
# 468211  Imperial Riding School Renaissance Vienna Hotel
# 11703                   Crowne Plaza London Kings Cross
# 140923                              Blakemore Hyde Park
#
#               Reviewer_Nationality  \
# 36193              United Kingdom
# 234813             United Kingdom
# 99627                    Bulgaria
# 395805                Switzerland
# 411211             United Kingdom
# ...                            ...
# 288501                    Germany
# 445710                    Romania
# 468211                    Lebanon
# 11703              United Kingdom
# 140923   United States of America
#
#                                           Negative_Review  \
# 36193    We had a very unpleasant stay and we believe ...
# 234813   Not the greatest of views our window looked i...
# 99627    Our room was booked for three persons We got ...
# 395805   My shower leaked all over the bathroom floor ...
# 411211   broken cupboards in room dark room with no ba...
# ...                                                   ...
# 288501   Check in time was 3 pm I arrived at 2 45 and ...
# 445710   i would take out some points for a the room w...
# 468211   Design beyond the lobby floors less than a 2 ...
# 11703    on arrival I was given a room card three time...
# 140923   Fell down on the marble steps no one from man...
#
#         Review_Total_Negative_Word_Counts  \
# 36193                           11.675812
# 234813                           1.863249
# 99627                            1.392784
# 395805                           1.628016
# 411211                           1.695226
# ...                                   ...
# 288501                           2.804180
# 445710                           3.207436
# 468211                           5.055692
# 11703                            5.593367
# 140923                           2.165691
#
#                                           Positive_Review  \
# 36193    The price is not bad and it is quite central ...
# 234813   Good location within walking distance of Spit...
# 99627                           Staff were very attentive
# 395805                                           Location
# 411211                                            nothing
# ...                                                   ...
# 288501                                   Central location
# 445710   overall a good hotel nice staff the room was ...
# 468211   Reception personal excellent Breakfast enjoya...
# 11703                                            Location
# 140923   The restaurant staff very friendly and accomm...
#
#         Review_Total_Positive_Word_Counts  \
# 36193                           -0.173867
# 234813                           0.835048
# 99627                           -0.586605
# 395805                          -0.724184
# 411211                          -0.724184
# ...                                   ...
# 288501                          -0.678324
# 445710                           1.706384
# 468211                          -0.357306
# 11703                           -0.724184
# 140923                          -0.449025
#
#                                                      Tags days_since_review  \
# 36193   [' Leisure trip ', ' Group ', ' Classic Double...           527 day
# 234813  [' Leisure trip ', ' Group ', ' Small Queen Ro...           59 days
# 99627   [' Leisure trip ', ' Family with young childre...           44 days
# 395805  [' Leisure trip ', ' Solo traveler ', ' Comfor...           142 day
# 411211  [' Leisure trip ', ' Family with young childre...           278 day
# ...                                                   ...               ...
# 288501  [' Leisure trip ', ' Solo traveler ', ' Double...           422 day
# 445710  [' Leisure trip ', ' Couple ', ' Deluxe Room '...           583 day
# 468211  [' Leisure trip ', ' Couple ', ' Double or Twi...           94 days
# 11703   [' Business trip ', ' Solo traveler ', ' Stand...           532 day
# 140923  [' Leisure trip ', ' Family with young childre...           39 days
#
#              lat       lng  Reviewer_Expertise_Level_Encoded  \
# 36193  -0.165893 -0.103323                          0.671697
# 234813  0.597202 -0.635422                          0.671697
# 99627  -0.169898 -0.116818                          0.671697
# 395805 -2.328707 -0.145427                         -1.610055
# 411211 -2.326333 -0.143488                          0.671697
# ...          ...       ...                               ...
# 288501 -2.326850 -0.142639                         -2.370640
# 445710 -0.361397  2.942791                          0.671697
# 468211 -0.359867  2.958017                          0.671697
# 11703   0.601124 -0.641706                          0.671697
# 140923  0.597253 -0.657008                          0.671697
#
#         Review_Count_Per_Hotel_Encoded
# 36193                         0.805851
# 234813                       -1.403862
# 99627                        -1.403862
# 395805                        0.805851
# 411211                        0.805851
# ...                                ...
# 288501                       -1.403862
# 445710                       -1.403862
# 468211                        0.805851
# 11703                         0.805851
# 140923                       -0.667291
#
# [31153 rows x 17 columns]
# Outliers in 'Review_Total_Positive_Word_Counts':
#                                             Hotel_Address Province_Name  \
# 392477                 Opernring 11 01 Innere Stadt 1010        Vienna
# 338500                        Hanger Lane Ealing  W5 3HL         London
# 309938      De Passage 90 Noord Holland Zuidoost 1101 AX     Amsterdam
# 254758  82 Gloucester Place Westminster Borough  W1U 6HN         London
# 424440               Rambla Catalunya 7 9 Eixample 08007     Barcelona
# ...                                                   ...           ...
# 88313      2 Caxton Street Westminster Borough  SW1H 0QW         London
# 445710                    Schlossallee 8 14 Penzing 1140        Vienna
# 503495                   Western Gateway Newham  E16 1FA         London
# 380095                               Molenwerf 1 1014 AG     Amsterdam
# 294517     Carburton Street Westminster Borough  W1W 5EE         London
#
#           Country_Name Review_Date  Average_Score  \
# 392477         Austria   8/19/2015       0.916642
# 338500  United Kingdom    9/6/2015       0.186864
# 309938     Netherlands    5/2/2017       0.916642
# 254758  United Kingdom   2/29/2016      -1.637580
# 424440           Spain    8/8/2015       1.463975
# ...                ...         ...            ...
# 88313   United Kingdom   12/5/2016       0.916642
# 445710         Austria  12/29/2015       0.734197
# 503495  United Kingdom    8/2/2017      -0.542913
# 380095     Netherlands    8/9/2016       0.186864
# 294517  United Kingdom   7/11/2017      -0.360469
#
#                                           Hotel_Name Reviewer_Nationality  \
# 392477                           Das Opernring Hotel             Belgium
# 338500                                      Hotel 55      United Kingdom
# 309938                                 Jaz Amsterdam             Iceland
# 254758                               Hotel 82 London      United Kingdom
# 424440                        H10 Metropolitan 4 Sup      United Kingdom
# ...                                              ...                  ...
# 88313          St Ermin s Hotel Autograph Collection      United Kingdom
# 445710  Austria Trend Hotel Park Royal Palace Vienna             Romania
# 503495                             Good Hotel London      United Kingdom
# 380095                   Golden Tulip Amsterdam West             Belgium
# 294517              Holiday Inn London Regent s Park             Germany
#
#                                           Negative_Review  \
# 392477                                        No Negative
# 338500            Room could have been a little brighter
# 309938   A small fault for us ladies The lights in the...
# 254758   The bathroom was rather oddly appointed with ...
# 424440   The shower was a bit leaky on the floor but i...
# ...                                                   ...
# 88313                                         No Negative
# 445710   i would take out some points for a the room w...
# 503495                                        No Negative
# 380095                                           Nothing
# 294517   Caution first world problem The air condition...
#
#         Review_Total_Negative_Word_Counts  \
# 392477                          -0.623496
# 338500                          -0.321054
# 309938                           0.888714
# 254758                           1.359179
# 424440                           0.183016
# ...                                   ...
# 88313                           -0.623496
# 445710                           3.207436
# 503495                          -0.623496
# 380095                          -0.522682
# 294517                          -0.052217
#
#                                           Positive_Review  \
# 392477   We often visit Vienna but last week was the f...
# 338500   Friendly helpful staff Nespresso coffee and r...
# 309938   The room was spacious and had everything that...
# 254758   The staff were delightful and couldn t have b...
# 424440   Everything was perfect the design of the hote...
# ...                                                   ...
# 88313    There were 5 of us all adults stayed in the f...
# 445710   overall a good hotel nice staff the room was ...
# 503495   The room was very large for a London hotel sh...
# 380095   The location was maybe not the most suitable ...
# 294517   All staff were very friendly The room was a g...
#
#         Review_Total_Positive_Word_Counts  \
# 392477                           4.595550
# 338500                           1.660524
# 309938                           1.981543
# 254758                           1.568805
# 424440                           2.577720
# ...                                   ...
# 88313                            1.843963
# 445710                           1.706384
# 503495                           1.706384
# 380095                           1.706384
# 294517                           2.807019
#
#                                                      Tags days_since_review  \
# 392477  [' Leisure trip ', ' Couple ', ' Double Room '...           715 day
# 338500  [' Leisure trip ', ' Family with older childre...           697 day
# 309938  [' Leisure trip ', ' Group ', ' Superior Doubl...           93 days
# 254758  [' Leisure trip ', ' Family with young childre...           521 day
# 424440  [' Leisure trip ', ' Couple ', ' Standard Doub...           726 day
# ...                                                   ...               ...
# 88313   [' Leisure trip ', ' Group ', ' Family Room wi...           241 day
# 445710  [' Leisure trip ', ' Couple ', ' Deluxe Room '...           583 day
# 503495  [' Business trip ', ' Group ', ' Double Room '...            1 days
# 380095  [' Leisure trip ', ' Couple ', ' Standard Quad...           359 day
# 294517  [' Leisure trip ', ' Group ', ' Standard Doubl...           23 days
#
#              lat       lng  Reviewer_Expertise_Level_Encoded  \
# 392477 -0.358134  2.953812                         -0.849471
# 338500  0.599665 -0.680518                          0.671697
# 309938  0.828543  0.460554                          0.671697
# 254758  0.599162 -0.651497                          0.671697
# 424440 -2.325025 -0.144071                          0.671697
# ...          ...       ...                               ...
# 88313   0.593193 -0.646136                          0.671697
# 445710 -0.361397  2.942791                          0.671697
# 503495  0.595939 -0.611398                          0.671697
# 380095  0.849100  0.440538                         -0.088887
# 294517  0.599930 -0.648035                          0.671697
#
#         Review_Count_Per_Hotel_Encoded
# 392477                        0.805851
# 338500                        0.805851
# 309938                       -0.667291
# 254758                        0.805851
# 424440                        0.805851
# ...                                ...
# 88313                         0.805851
# 445710                       -1.403862
# 503495                        0.805851
# 380095                        0.069280
# 294517                        0.805851
#
# [28924 rows x 17 columns]
# Outliers in 'lat':
#                                             Hotel_Address Province_Name  \
# 378335                                Marina 19 21 08005     Barcelona
# 395805                Paral lel 115 Sants Montju c 08004     Barcelona
# 411211              Pintor Fortuny 13 Ciutat Vella 08001     Barcelona
# 412927  Pla a Rosa dels Vents 1 Passeig Joan de Borbo ...    Barcelona
# 424440               Rambla Catalunya 7 9 Eixample 08007     Barcelona
# ...                                                   ...           ...
# 400443               Passeig de Gracia 84 Eixample 08008     Barcelona
# 292899                     Calabria 90 92 Eixample 08015     Barcelona
# 372722                      Loreto 21 25 Les Corts 08029     Barcelona
# 283116                         Balmes 117 Eixample 08008     Barcelona
# 279369             Avenida Meridiana 151 Sant Mart 08026     Barcelona
#
#        Country_Name Review_Date  Average_Score  \
# 378335        Spain   5/30/2017       0.734197
# 395805        Spain   3/14/2017      -0.360469
# 411211        Spain  10/29/2016      -0.907802
# 412927        Spain   7/17/2016       0.186864
# 424440        Spain    8/8/2015       1.463975
# ...             ...         ...            ...
# 400443        Spain   6/19/2017       0.369309
# 292899        Spain  11/24/2015       0.734197
# 372722        Spain   4/17/2016      -0.725358
# 283116        Spain   8/18/2016       1.646419
# 279369        Spain   3/30/2016      -0.907802
#
#                                            Hotel_Name  \
# 378335                           Hotel Arts Barcelona
# 395805                               Silken Concordia
# 411211                                 Silken Ramblas
# 412927                                    W Barcelona
# 424440                         H10 Metropolitan 4 Sup
# ...                                               ...
# 400443                        Royal Passeig de Gracia
# 292899  TWO Hotel Barcelona by Axel 4 Sup Adults Only
# 372722                                    Hotel Derby
# 283116                            Olivia Balmes Hotel
# 279369                               Catalonia Atenas
#
#               Reviewer_Nationality  \
# 378335                    Belgium
# 395805                Switzerland
# 411211             United Kingdom
# 412927                  Australia
# 424440             United Kingdom
# ...                            ...
# 400443   United States of America
# 292899             United Kingdom
# 372722                     Russia
# 283116                    Lebanon
# 279369                    Belgium
#
#                                           Negative_Review  \
# 378335                                   Crowded poolside
# 395805   My shower leaked all over the bathroom floor ...
# 411211   broken cupboards in room dark room with no ba...
# 412927   service in the dining room I only went there ...
# 424440   The shower was a bit leaky on the floor but i...
# ...                                                   ...
# 400443   It was disappointing that on a Friday night w...
# 292899   Bathroom was not up to normal high standard n...
# 372722   Old i would give it 3 stars very loud in the ...
# 283116                                                All
# 279369   The room was old There were works ongoing ins...
#
#         Review_Total_Negative_Word_Counts  \
# 378335                          -0.522682
# 395805                           1.628016
# 411211                           1.695226
# 412927                           0.451853
# 424440                           0.183016
# ...                                   ...
# 400443                           0.519062
# 292899                          -0.253845
# 372722                          -0.186636
# 283116                          -0.556287
# 279369                           0.149411
#
#                                           Positive_Review  \
# 378335                              Clean and comfortable
# 395805                                           Location
# 411211                                            nothing
# 412927                                location facilities
# 424440   Everything was perfect the design of the hote...
# ...                                                   ...
# 400443   Be sure to visit the rooftop bar The view is ...
# 292899   Off season prices are great easy location to ...
# 372722                                              Price
# 283116       Staff and the facility to the center of town
# 279369                                    Good breakfast
#
#         Review_Total_Positive_Word_Counts  \
# 378335                          -0.632465
# 395805                          -0.724184
# 411211                          -0.724184
# 412927                          -0.678324
# 424440                           2.577720
# ...                                   ...
# 400443                          -0.219727
# 292899                          -0.219727
# 372722                          -0.724184
# 283116                          -0.357306
# 279369                          -0.632465
#
#                                                      Tags days_since_review  \
# 378335  [' Leisure trip ', ' Family with young childre...           65 days
# 395805  [' Leisure trip ', ' Solo traveler ', ' Comfor...           142 day
# 411211  [' Leisure trip ', ' Family with young childre...           278 day
# 412927  [' Leisure trip ', ' Solo traveler ', ' Mega R...           382 day
# 424440  [' Leisure trip ', ' Couple ', ' Standard Doub...           726 day
# ...                                                   ...               ...
# 400443  [' Business trip ', ' Couple ', ' Double or Tw...           45 days
# 292899  [' Leisure trip ', ' Solo traveler ', ' Double...           618 day
# 372722  [' Business trip ', ' Solo traveler ', ' Doubl...           473 day
# 283116  [' Leisure trip ', ' Group ', ' Standard Doubl...           350 day
# 279369  [' Business trip ', ' Solo traveler ', ' Doubl...           491 day
#
#              lat       lng  Reviewer_Expertise_Level_Encoded  \
# 378335 -2.325314 -0.137620                          0.671697
# 395805 -2.328707 -0.145427                         -1.610055
# 411211 -2.326333 -0.143488                          0.671697
# 412927 -2.330540 -0.139107                          0.671697
# 424440 -2.325025 -0.144071                          0.671697
# ...          ...       ...                               ...
# 400443 -2.322967 -0.145110                          0.671697
# 292899 -2.327454 -0.146532                         -1.610055
# 372722 -2.324382 -0.149617                         -0.849471
# 283116 -2.323712 -0.146014                          0.671697
# 279369 -2.318254 -0.139882                          0.671697
#
#         Review_Count_Per_Hotel_Encoded
# 378335                        0.805851
# 395805                        0.805851
# 411211                        0.805851
# 412927                       -1.403862
# 424440                        0.805851
# ...                                ...
# 400443                       -1.403862
# 292899                        0.805851
# 372722                        0.805851
# 283116                        0.805851
# 279369                       -0.667291
#
# [47891 rows x 17 columns]
# Outliers in 'lng':
#                                             Hotel_Address Province_Name  \
# 392477                 Opernring 11 01 Innere Stadt 1010        Vienna
# 435939           Rotenturmstra e 15 01 Innere Stadt 1010        Vienna
# 434046              Rooseveltplatz 15 09 Alsergrund 1090        Vienna
# 396445                  Parkring 12 01 Innere Stadt 1010        Vienna
# 268985                 Am Stadtpark 1 03 Landstra e 1030        Vienna
# ...                                                   ...           ...
# 445710                    Schlossallee 8 14 Penzing 1140        Vienna
# 468211                  Ungargasse 60 03 Landstra e 1030        Vienna
# 500649          Wagramer Stra e 16 18 22 Donaustadt 1220        Vienna
# 502048              Weihburggasse 3 01 Innere Stadt 1010        Vienna
# 353962  K rntnerstra e 18 Eingang Neuer Markt 3 01 Inn...       Vienna
#
#        Country_Name Review_Date  Average_Score  \
# 392477      Austria   8/19/2015       0.916642
# 435939      Austria   9/14/2016       0.551753
# 434046      Austria    7/2/2017       0.004420
# 396445      Austria   9/27/2016       1.099086
# 268985      Austria   8/28/2016      -0.725358
# ...             ...         ...            ...
# 445710      Austria  12/29/2015       0.734197
# 468211      Austria    5/1/2017      -0.542913
# 500649      Austria   5/15/2016       0.369309
# 502048      Austria   3/12/2017       1.463975
# 353962      Austria   7/15/2017       0.369309
#
#                                              Hotel_Name  \
# 392477                              Das Opernring Hotel
# 435939                                      Hotel Lam e
# 434046                                     Hotel Regina
# 396445                                Hotel Am Parkring
# 268985                                    Hilton Vienna
# ...                                                 ...
# 445710     Austria Trend Hotel Park Royal Palace Vienna
# 468211  Imperial Riding School Renaissance Vienna Hotel
# 500649             Park Inn by Radisson Uno City Vienna
# 502048                         Hotel Kaiserin Elisabeth
# 353962                  Austria Trend Hotel Europa Wien
#
#               Reviewer_Nationality  \
# 392477                    Belgium
# 435939       United Arab Emirates
# 434046   United States of America
# 396445             United Kingdom
# 268985             United Kingdom
# ...                            ...
# 445710                    Romania
# 468211                    Lebanon
# 500649                Netherlands
# 502048                Switzerland
# 353962                   Thailand
#
#                                           Negative_Review  \
# 392477                                        No Negative
# 435939                                 Nothing to dislike
# 434046                                  Rooms a bit small
# 396445                                        No Negative
# 268985           Staffs in the reception were unfriendly
# ...                                                   ...
# 445710   i would take out some points for a the room w...
# 468211   Design beyond the lobby floors less than a 2 ...
# 500649   The room was rather hot Wifi connection wasn ...
# 502048   there is construction working going on right ...
# 353962   The bathroom doesn t have a inside door so al...
#
#         Review_Total_Negative_Word_Counts  \
# 392477                          -0.623496
# 435939                          -0.489078
# 434046                          -0.455473
# 396445                          -0.623496
# 268985                          -0.354659
# ...                                   ...
# 445710                           3.207436
# 468211                           5.055692
# 500649                           0.720690
# 502048                           0.586272
# 353962                           0.183016
#
#                                           Positive_Review  \
# 392477   We often visit Vienna but last week was the f...
# 435939   It is small yet comfortable and welcoming It ...
# 434046                       Excellent location and staff
# 396445                                     Great location
# 268985                                        No Positive
# ...                                                   ...
# 445710   overall a good hotel nice staff the room was ...
# 468211   Reception personal excellent Breakfast enjoya...
# 500649   Decent hotel with two subway stations within ...
# 502048   lovel rooms great and friendly service except...
# 353962   The location is excellent Walking distance to...
#
#         Review_Total_Positive_Word_Counts  \
# 392477                           4.595550
# 435939                           0.330591
# 434046                          -0.586605
# 396445                          -0.678324
# 268985                          -0.815904
# ...                                   ...
# 445710                           1.706384
# 468211                          -0.357306
# 500649                           0.926768
# 502048                          -0.403166
# 353962                           0.697469
#
#                                                      Tags days_since_review  \
# 392477  [' Leisure trip ', ' Couple ', ' Double Room '...           715 day
# 435939  [' Leisure trip ', ' Solo traveler ', ' Junior...           323 day
# 434046  [' Leisure trip ', ' Solo traveler ', ' Single...           32 days
# 396445  [' Business trip ', ' Solo traveler ', ' Singl...           310 day
# 268985  [' Leisure trip ', ' Solo traveler ', ' King C...           340 day
# ...                                                   ...               ...
# 445710  [' Leisure trip ', ' Couple ', ' Deluxe Room '...           583 day
# 468211  [' Leisure trip ', ' Couple ', ' Double or Twi...           94 days
# 500649  [' Leisure trip ', ' Couple ', ' Standard Doub...           445 day
# 502048  [' Leisure trip ', ' Couple ', ' Double Room '...           144 day
# 353962  [' Leisure trip ', ' Group ', ' Classic Room '...           19 days
#
#              lat       lng  Reviewer_Expertise_Level_Encoded  \
# 392477 -0.358134  2.953812                         -0.849471
# 435939 -0.355934  2.955344                         -1.610055
# 434046 -0.354183  2.952164                         -2.370640
# 396445 -0.357271  2.956158                         -1.610055
# 268985 -0.357100  2.957362                          0.671697
# ...          ...       ...                               ...
# 445710 -0.361397  2.942791                          0.671697
# 468211 -0.359867  2.958017                          0.671697
# 500649 -0.349061  2.965572                         -0.849471
# 502048 -0.356809  2.954932                         -0.088887
# 353962 -0.357105  2.954670                         -1.610055
#
#         Review_Count_Per_Hotel_Encoded
# 392477                        0.805851
# 435939                        0.805851
# 434046                        0.805851
# 396445                        0.805851
# 268985                       -1.403862
# ...                                ...
# 445710                       -1.403862
# 468211                        0.805851
# 500649                        0.805851
# 502048                        0.805851
# 353962                       -1.403862
#
# [29100 rows x 17 columns]
# No outliers in 'Reviewer_Expertise_Level_Encoded'.
# No outliers in 'Review_Count_Per_Hotel_Encoded'.
#                                             Hotel_Address Province_Name  \
# 35593         111 avenue de la Bourdonnais 7th arr 75007         Paris
# 363006                       Lakeside Way Brent  HA9 0BU         London
# 303312         Corso Concordia 1 Milan City Center 20129         Milan
# 263174  97 Cromwell Road Kensington and Chelsea  SW7 4DN         London
# 36193          112 boulevard de S bastopol 3rd arr 75003         Paris
# ...                                                   ...           ...
# 341690  Herengracht 542 556 Amsterdam City Center 1017...    Amsterdam
# 249784       8 Place Marguerite de Navarre 1st arr 75001         Paris
# 97414             20 Lavington Street Southwark  SE1 0NZ         London
# 173126  4 18 Harrington Gardens Kensington and Chelsea...        London
# 294517     Carburton Street Westminster Borough  W1W 5EE         London
#
#           Country_Name Review_Date  Average_Score  \
# 35593           France   8/27/2015       0.734197
# 363006  United Kingdom   3/27/2016       0.734197
# 303312           Italy   2/11/2017       1.099086
# 263174  United Kingdom   4/16/2017      -1.090247
# 36193           France   2/23/2016      -0.178025
# ...                ...         ...            ...
# 341690     Netherlands    5/1/2016       2.011308
# 249784          France   7/21/2017       0.004420
# 97414   United Kingdom    4/4/2016       1.281531
# 173126  United Kingdom   1/22/2017      -1.090247
# 294517  United Kingdom   7/11/2017      -0.360469
#
#                                            Hotel_Name  \
# 35593                         H tel de la Bourdonnais
# 363006                          Hilton London Wembley
# 303312                Ch teau Monfort Relais Ch teaux
# 263174            Holiday Inn London Kensington Forum
# 36193   Best Western Premier Marais Grands Boulevards
# ...                                               ...
# 341690                      Waldorf Astoria Amsterdam
# 249784                       Novotel Paris Les Halles
# 97414                        citizenM London Bankside
# 173126             Millennium Gloucester Hotel London
# 294517               Holiday Inn London Regent s Park
#
#               Reviewer_Nationality  \
# 35593              United Kingdom
# 363006             United Kingdom
# 303312                    Romania
# 263174                    Nigeria
# 36193              United Kingdom
# ...                            ...
# 341690   United States of America
# 249784                  Australia
# 97414                 Switzerland
# 173126             United Kingdom
# 294517                    Germany
#
#                                           Negative_Review  \
# 35593    Wifi kept failing Room looking out onto inter...
# 363006                                        No Negative
# 303312     Shower presure and thw gyn ahould be improved
# 263174   My room was a bit noisy because of the rail l...
# 36193    We had a very unpleasant stay and we believe ...
# ...                                                   ...
# 341690                                        No Negative
# 249784   Room is small driving and finding parking is ...
# 97414    The printer downstairs is broken So super min...
# 173126   lower the of the room price for booking 4 to ...
# 294517   Caution first world problem The air condition...
#
#         Review_Total_Negative_Word_Counts  \
# 35593                            0.216620
# 363006                          -0.623496
# 303312                          -0.287450
# 263174                          -0.119426
# 36193                           11.675812
# ...                                   ...
# 341690                          -0.623496
# 249784                          -0.220240
# 97414                           -0.018612
# 173126                           0.149411
# 294517                          -0.052217
#
#                                           Positive_Review  \
# 35593    Location fabulous Staff friendly and very hel...
# 363006                                     Staff friendly
# 303312   Staff and breakfast We are frequent clients a...
# 263174                           The staff were courteous
# 36193    The price is not bad and it is quite central ...
# ...                                                   ...
# 341690   Superb hotel friendly staff cozy atmosphere a...
# 249784             The location was great staff are great
# 97414                                         No Positive
# 173126                                      the price ish
# 294517   All staff were very friendly The room was a g...
#
#         Review_Total_Positive_Word_Counts  \
# 35593                            0.055432
# 363006                          -0.678324
# 303312                          -0.311446
# 263174                          -0.586605
# 36193                           -0.173867
# ...                                   ...
# 341690                           0.697469
# 249784                          -0.449025
# 97414                           -0.815904
# 173126                          -0.632465
# 294517                           2.807019
#
#                                                      Tags days_since_review  \
# 35593   [' Leisure trip ', ' Family with older childre...           707 day
# 363006  [' Leisure trip ', ' Family with young childre...           494 day
# 303312  [' Leisure trip ', ' Group ', ' Superior Doubl...           173 day
# 263174  [' Business trip ', ' Solo traveler ', ' Doubl...           109 day
# 36193   [' Leisure trip ', ' Group ', ' Classic Double...           527 day
# ...                                                   ...               ...
# 341690  [' Leisure trip ', ' Family with older childre...           459 day
# 249784  [' Leisure trip ', ' Family with young childre...           13 days
# 97414   [' Business trip ', ' Group ', ' Double Room '...           486 day
# 173126  [' Leisure trip ', ' Solo traveler ', ' Standa...           193 day
# 294517  [' Leisure trip ', ' Group ', ' Standard Doubl...           23 days
#
#              lat       lng  Reviewer_Expertise_Level_Encoded  \
# 35593  -0.169845 -0.114142                          0.671697
# 363006  0.610161 -0.678778                          0.671697
# 303312 -1.147306  1.391808                         -0.849471
# 263174  0.591844 -0.657307                          0.671697
# 36193  -0.165893 -0.103323                          0.671697
# ...          ...       ...                               ...
# 341690  0.843088  0.451421                          0.671697
# 249784 -0.168205 -0.104990                          0.671697
# 97414   0.594996 -0.638842                         -0.849471
# 173126  0.591635 -0.656941                          0.671697
# 294517  0.599930 -0.648035                          0.671697
#
#         Review_Count_Per_Hotel_Encoded
# 35593                         0.805851
# 363006                       -1.403862
# 303312                        0.805851
# 263174                       -1.403862
# 36193                         0.805851
# ...                                ...
# 341690                        0.805851
# 249784                        0.805851
# 97414                        -1.403862
# 173126                       -0.667291
# 294517                        0.805851
#
# [409646 rows x 17 columns]
# Outliers removed from the dataset.
#
#
# After data preprocessing
# Training data shape: (409646, 17)
# Training labels shape: (409646,)
# Testing data shape: (102496, 17)
# Testing labels shape: (102496,)
#
#
# Deserialized data
# Training data shape: (409646, 17)
# Training labels shape: (409646,)
# Testing data shape: (102496, 17)
# Testing labels shape: (102496,)

# %% [markdown]
# ## Eploratory Data Analysis (EDA)

# %%
class EDA:
    def __init__(self, data_loader):
        self.data_loader = data_loader
        self._data = self.data_loader.data_train.select_dtypes(include=['number'])
        self._labels = self.data_loader.labels_train

    def perform_eda(self):
        print("Exploratory Data Analysis (EDA) Report:")
        print("--------------------------------------")

        # Basic information of dataset
        print("\nBasic Information about the dataset:")
        print(self.data_loader.data_train.info())

        # Summary statistics
        print("\nSummary Statistics for train data:")
        print(self.data_loader.data_train.describe())
        print("\nSummary Statistics for test data:")
        print(self.data_loader.data_test.describe())

        # Distribution analysis
        print("\nDistribution analysis")
        self.plot_distributions()

        # Correlation analysis
        print("\nCorrelation analysis")
        self.plot_correlation_heatmap()

        # Feature Importance analysis
        print("\nFeature Importance analysis")
        self.plot_feature_importance()

        # Violin plots
        print("\nViolin plots")
        self.violin_plots()

    def plot_distributions(self):
        """
        Plots distributions of the features.
        """
        num_cols = len(self._data.columns)
        fig, axes = plt.subplots(num_cols, 1, figsize=(10, 5 * num_cols))
        for i, feature in enumerate(self._data.columns):
            sns.histplot(data=self._data, x=feature, ax=axes[i])
            axes[i].set_title(f"Distribution of {feature}")
            axes[i].set_xlabel(feature)
            axes[i].set_ylabel("Frequency")
        plt.tight_layout()
        plt.show()

    def plot_correlation_heatmap(self):
        """
        Plots a correlation heatmap between features and labels.
        """
        # Concatenate features and labels horizontally for correlation calculation
        data_with_labels = pd.concat([self._data, self._labels], axis=1)

        # Compute the correlation matrix
        corr_matrix = data_with_labels.corr()

        # Plot the heatmap
        plt.figure(figsize=(12, 8))
        sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f")
        plt.title("Correlation Heatmap between Features and Labels")
        plt.show()

    def plot_feature_importance(self, n_estimators=5, n_repeats=2):
        """
        Computes and visualizes feature importance using permutation importance.
        """
        # Fit a random forest classifier to compute feature importance
        clf = RandomForestClassifier(n_estimators=n_estimators)
        clf.fit(self._data, self._labels)

        # Compute permutation importance
        result = permutation_importance(clf, self._data, self._labels,
                                        n_repeats=n_repeats)
        sorted_idx = result.importances_mean.argsort()

        # Plot feature importance
        plt.figure(figsize=(10, 8))
        plt.barh(range(len(sorted_idx)), result.importances_mean[sorted_idx], align='center')
        plt.yticks(range(len(sorted_idx)), self._data.columns[sorted_idx])
        plt.xlabel('Permutation Importance')
        plt.title('Feature Importance')
        plt.show()

    def violin_plots(self):
        print("TO DO: violin_plots")

# %%
class DataVisualization:
    """
    A class responsible for data visualization.

    Attributes:
        data_loader (DataLoader): An object of the DataLoader class containing the dataset.

    Methods:
        perform_visualization(): Performs data visualization.
    """

    def __init__(self, data_loader):
        """
        Initializes the DataVisualization class with a DataLoader object.
        """
        self.data_loader = data_loader
        self._data = self.data_loader.data_train.select_dtypes(include=['number'])

    def perform_visualization(self):
        """
        Performs data visualization.
        """
        # Pairplot
        self.plot_pairplot()

        # Boxplot
        self.plot_boxplot()

        # Ridgeplot
        self.plot_ridgeplot()

    def plot_pairplot(self):
        """
        Plots pairplot for all features.
        """
        sns.pairplot(self._data, diag_kind='kde')
        plt.title("Pairplot of Features")
        plt.show()

    def plot_boxplot(self):
        """
        Plots boxplot for all features.
        """
        # Create a single figure and axis for all boxplots
        fig, ax = plt.subplots(figsize=(15, 8))

        # Plot boxplots for each feature
        sns.boxplot(data=self._data, ax=ax)
        ax.set_title("Boxplot of all Features")
        ax.set_xlabel("Feature")
        ax.set_ylabel("Value")
        ax.set_xticks(range(len(self._data.columns)))
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

        plt.tight_layout()
        plt.show()

    def plot_ridgeplot(self):
        """
        Plots overlapping densities (ridge plot) for all features.
        """

        # Create a single figure and axis for all boxplots
        fig, axes = plt.subplots(len(self._data.columns), 1, figsize=(10, 8), sharex=True)

        # Generate a gradient of darker colors for the plots
        num_plots = len(self._data.columns)
        cmap = plt.get_cmap('Blues')
        colors = [cmap(1 - i / (num_plots + 1)) for i in range(1, num_plots + 1)]

        # Plot overlapping densities for each numerical feature
        for i, (feature, color) in enumerate(zip(self._data.columns, colors)):
            sns.kdeplot(data=self._data[feature], ax=axes[i], color=color, fill=True, linewidth=2)
            axes[i].set_ylabel(feature, rotation=0, labelpad=40)  # Rotate y-axis label
            axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position
            axes[i].spines['top'].set_visible(False)

            # Remove box structure around the plots
            axes[i].spines['right'].set_visible(False)
            axes[i].spines['left'].set_visible(False)
            axes[i].spines['bottom'].set_visible(False)

        # Adjust plot aesthetics
        axes[-1].set_xlabel("Value")

        plt.tight_layout()
        plt.show()

# %%
eda = EDA(data_loader)
eda.perform_eda()
# Out:
# Exploratory Data Analysis (EDA) Report:
# --------------------------------------
#
# Basic Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 409646 entries, 35593 to 294517
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Hotel_Address                      409646 non-null  object
#  1   Province_Name                      409646 non-null  object
#  2   Country_Name                       409646 non-null  object
#  3   Review_Date                        409646 non-null  object
#  4   Average_Score                      409646 non-null  float64
#  5   Hotel_Name                         409646 non-null  object
#  6   Reviewer_Nationality               409646 non-null  object
#  7   Negative_Review                    409646 non-null  object
#  8   Review_Total_Negative_Word_Counts  409646 non-null  float64
#  9   Positive_Review                    409646 non-null  object
#  10  Review_Total_Positive_Word_Counts  409646 non-null  float64
#  11  Tags                               409646 non-null  object
#  12  days_since_review                  409646 non-null  object
#  13  lat                                409646 non-null  float64
#  14  lng                                409646 non-null  float64
#  15  Reviewer_Expertise_Level_Encoded   409646 non-null  float64
#  16  Review_Count_Per_Hotel_Encoded     409646 non-null  float64
# dtypes: float64(7), object(10)
# memory usage: 56.3+ MB
# None
#
# Summary Statistics for train data:
#        Average_Score  Review_Total_Negative_Word_Counts  \
# count  409646.000000                      409646.000000
# mean        0.001199                           0.000140
# std         1.001876                           1.000153
# min        -5.833801                          -0.623496
# 25%        -0.542913                          -0.556287
# 50%         0.004420                          -0.321054
# 75%         0.734197                           0.149411
# max         2.558641                          13.087208
#
#        Review_Total_Positive_Word_Counts            lat            lng  \
# count                      409646.000000  409646.000000  409646.000000
# mean                           -0.000611       0.000134       0.000065
# std                             0.998997       1.000381       1.000366
# min                            -0.815904      -2.342102      -0.697590
# 25%                            -0.586605      -0.354777      -0.648261
# 50%                            -0.311446       0.593504      -0.616976
# 75%                             0.193011       0.598210       0.437786
# max                            17.298707       0.853308       2.967366
#
#        Reviewer_Expertise_Level_Encoded  Review_Count_Per_Hotel_Encoded
# count                     409646.000000                   409646.000000
# mean                           0.001387                        0.002435
# std                            0.999472                        0.998800
# min                           -2.370640                       -1.403862
# 25%                           -0.849471                       -1.403862
# 50%                            0.671697                        0.805851
# 75%                            0.671697                        0.805851
# max                            0.671697                        0.805851
#
# Summary Statistics for test data:
#        Average_Score  Review_Total_Negative_Word_Counts  \
# count  102496.000000                      102496.000000
# mean        0.000103                          -0.002436
# std         1.001375                           0.989006
# min        -5.833801                          -0.623496
# 25%        -0.542913                          -0.556287
# 50%         0.004420                          -0.321054
# 75%         0.734197                           0.149411
# max         2.558641                          12.885580
#
#        Review_Total_Positive_Word_Counts            lat            lng  \
# count                      102496.000000  102496.000000  102496.000000
# mean                           -0.003241      -0.001596      -0.004331
# std                             1.000497       1.002041       0.995341
# min                            -0.815904      -2.342102      -0.697590
# 25%                            -0.586605      -0.354777      -0.648201
# 50%                            -0.311446       0.593504      -0.616976
# 75%                             0.193011       0.598238       0.437056
# max                            16.885969       0.853308       2.967366
#
#        Reviewer_Expertise_Level_Encoded  Review_Count_Per_Hotel_Encoded
# count                     102496.000000                   102496.000000
# mean                          -0.002630                        0.009691
# std                            1.001721                        0.996195
# min                           -2.370640                       -1.403862
# 25%                           -0.849471                       -1.403862
# 50%                            0.671697                        0.805851
# 75%                            0.671697                        0.805851
# max                            0.671697                        0.805851
#
# Distribution analysis
# Correlation analysis
# Feature Importance analysis
# Violin plots
# TO DO: violin_plots

# %%
data_visualization = DataVisualization(data_loader)
data_visualization.perform_visualization()

# %%
class FeatureAnalysis:
    def __init__(self, data_loader):
        self.data_loader = data_loader

        self._data = self.data_loader.data_train.select_dtypes(include=['number'])
        self._targets = self.data_loader.labels_train

    def perform_feature_analysis(self):
        # Compute and plot PCA projection
        print('PCA')
        self.plot_projection(self.compute_pca(), 'PCA Projection')
        # Compute and plot LDA projection
        print('LDA')
        self.plot_projection(self.compute_lda(), 'LDA Projection')
        # Compute and plot t-SNE projection
        print('t-SNE')
        #self.plot_projection(self.compute_tsne(), 't-SNE Projection')
        # Compute and plot UMAP projection
        print('UMAP')
        self.plot_projection(self.compute_umap(), 'UMAP Projection')
        # Compute and plot LLE projection
        # print('LLE')
        # self.plot_projection(self.compute_lle(), 'LLE Projection')

    def compute_pca(self, n_components=2):
        """
        Compute Principal Component Analysis (PCA) on the dataset.

        Parameters:
        - n_components: The number of components to keep.

        Returns:
        - pca_projection: The projected data using PCA.
        """
        return PCA(n_components=n_components).fit_transform(self._data), self._data

    def compute_lda(self, n_components=2):
        """
        Perform Linear Discriminant Analysis (LDA) on the input data.

        Parameters:
        - n_components: The number of components to keep

        Returns:
            array-like: The reduced-dimensional representation of the data using LDA.
        """
        return LinearDiscriminantAnalysis(n_components=n_components).fit_transform(self._data, self._targets), self._data

    def compute_tsne(self, n_components=2, perplexity=50, learning_rate=10, n_iter=3000):

        """
        Compute t-Distributed Stochastic Neighbor Embedding (t-SNE) on the dataset.

        Parameters:
        - n_components: The number of components to embed the data into.
        - perplexity: The perplexity parameter for t-SNE.

        Returns:
        - tsne_projection: The projected data using t-SNE.
        """
        test = self._data.sample(n=10000, random_state=42)
        return TSNE(n_components=n_components, perplexity=perplexity, learning_rate=learning_rate, n_iter=n_iter).fit_transform(test), test

    def compute_umap(self, n_components=2, n_neighbors=10, min_dist=0.5, metric='euclidean'):
        """
        Compute Uniform Manifold Approximation and Projection (UMAP) on the dataset.

        Parameters:
        - n_components: The number of components to embed the data into.
        - n_neighbors: The number of neighbors to consider for each point.
        - min_dist: The minimum distance between embedded points.
        - metric: The distance metric to use.

        Returns:
        - umap_projection: The projected data using UMAP.
        """
        #test = self._data.sample(n=10000, random_state=42)
        test = self._data
        return umap.UMAP(n_components=n_components, n_neighbors=n_neighbors, min_dist=min_dist,
                         metric=metric).fit_transform(test), test

    def compute_lle(self, n_components=2, n_neighbors=20):
        """
        Compute Locally Linear Embedding (LLE) on the dataset.

        Parameters:
        - n_components: The number of components to embed the data into.
        - n_neighbors: The number of neighbors to consider for each point.

        Returns:
        - lle_projection: The projected data using LLE.
        """
        return LocallyLinearEmbedding(n_neighbors=n_neighbors, n_components=n_components).fit_transform(self._data)

    def plot_projection(self, projection, title):
        """
        Plot the 2D projection of the dataset.

        Parameters:
        - projection: The projected data.
        - title: The title of the plot.
        """
        plt.figure(figsize=(8, 6))
        plt.scatter(projection[0][:, 0], projection[0][:, 1], c=self._targets.loc[projection[1].index], alpha=0.5)

        classes = sorted(self._targets.unique())
        total_classes = len(classes)

        norm = Normalize(vmin=0, vmax=total_classes - 1)
        sm = cm.ScalarMappable(cmap='viridis', norm=norm)
        sm.set_array([])

        legend_colors = [sm.to_rgba(i) for i in range(total_classes)]

        legend_elements = [Line2D([0], [0], marker='o', color='w', label=class_,
                                  markerfacecolor=legend_colors[i])
                           for i, class_ in enumerate(classes)]

        legend1 = plt.legend(handles=legend_elements, title="Classes")

        plt.gca().add_artist(legend1)

        plt.title(title)
        plt.xlabel('Component 1')
        plt.ylabel('Component 2')
        plt.grid(True)
        plt.savefig(title + ".png", dpi=300, bbox_inches='tight')
        plt.show()

    def relevant_feature_identification(self, num_features=7):
        """
        Perform feature relevant feature identification using mutual information between each feature and the target
        variable. Mutual information measures the amount of information obtained about one random variable through
        another random variable. It quantifies the amount of uncertainty reduced for one variable given the knowledge
        of another variable. In feature selection, mutual information helps identify the relevance of features with
        respect to the target variable.

        Parameters:
            num_features (int): Number of features to select.

        Returns:
            selected_features (list): List of selected feature names.
        """
        try:
            # Check if data_train is not None
            if self.data_loader.data_train is None or self.data_loader.labels_train is None:
                raise ValueError("Training data or labels have not been loaded yet.")

            data = self.data_loader.data_train.select_dtypes(include=['number'])

            # Perform feature selection using mutual information
            mutual_info = mutual_info_classif(data, self.data_loader.labels_train)

            selected_features_indices = np.argsort(mutual_info)[::-1][:num_features]
            selected_features = data.columns[selected_features_indices]

            print(f"{num_features} relevant features identified.")
            print(selected_features.tolist())
            return selected_features.tolist()

        except ValueError as ve:
            print("Error:", ve)

    def select_features_mrmr(self, k=5):
        """
        Select features using mRMR (minimum Redundancy Maximum Relevance).

        Parameters:
        - k (int): The number of features to select. Default is 5.

        Returns:
        - List: The selected features as a list.
        """

        data = self.data_loader.data_train.select_dtypes(include=['number'])
        # Return the selected features
        selected_features = mrmr_classif(X=data, y=self.data_loader.labels_train, K=k)

        print("Selected features (mRMR):", selected_features)

        return selected_features

# %%
class FeatureAnalysisAndGenerator(FeatureAnalysis):
    def __init__(self, data_loader):
        super().__init__(data_loader)

    def generate_features(self):

        # New Features
        # Simple Combinations

        mean_words_positive = self.data_loader.data_train['Review_Total_Positive_Word_Counts'].mean()
        print('Mean of Positive Words: ', mean_words_positive)
        mean_words_negative = self.data_loader.data_train['Review_Total_Negative_Word_Counts'].mean()
        print('Mean of Negative Words: ', mean_words_negative)

        self.data_loader.data_train['Ratio_WordCount_Between_Positive_Negative_Reviews'] = \
            (self.data_loader.data_train['Review_Total_Positive_Word_Counts'] / self.data_loader.data_train['Review_Total_Negative_Word_Counts'])

        #self.data_loader.data['Deviation_Between_AverageScore_ReviewerScore'] = (
        #        self.data_loader.data['Reviewer_Score'] - self.data_loader.data['Average_Score'])

        self.data_loader.data_train['Ratio_Between_AverageScore_TotalReviews'] = \
            (self.data_loader.data_train['Review_Count_Per_Hotel_Encoded'] / self.data_loader.data_train['Average_Score'])

        self.data_loader.data_train['Total_Tags'] = self.data_loader.data_train['Tags'].apply(self.count_tags)

        self.data_loader.data_train['Total_Review_Words'] = self.data_loader.data_train['Review_Total_Positive_Word_Counts'] + self.data_loader.data_train[
            'Review_Total_Negative_Word_Counts']

        self.data_loader.data_train['Ratio_Total_Positive_Words'] = self.data_loader.data_train['Review_Total_Positive_Word_Counts'] / \
                                                      self.data_loader.data_train[
                                                          'Total_Review_Words']

        self.data_loader.data_train['Ratio_Positive_Words_Mean'] = self.data_loader.data_train[
                                                         'Review_Total_Positive_Word_Counts'] / mean_words_positive

        self.data_loader.data_train['Ratio_Total_Negative_Words'] = self.data_loader.data_train['Review_Total_Negative_Word_Counts'] / \
                                                      self.data_loader.data_train[
                                                          'Total_Review_Words']

        self.data_loader.data_train['Ratio_Negative_Words_Mean'] = self.data_loader.data_train[
                                                         'Review_Total_Negative_Word_Counts'] / mean_words_negative

        self.data_loader.data_train['Reviewer_Has_Given_Positive_Review'] = self.data_loader.data_train['Review_Total_Positive_Word_Counts'].apply(
            lambda review: 0 if review == 0 else 1)

        self.data_loader.data_train['Reviewer_Has_Given_Negative_Review'] = self.data_loader.data_train['Review_Total_Negative_Word_Counts'].apply(
            lambda review: 0 if review == 0 else 1)

        #self.data_loader.data['Log_Reviewer_Score'] = np.log(self.data_loader.data['Reviewer_Score'])

        self.data_loader.data_train['Square_Ratio_WordCount'] = np.power(
            self.data_loader.data_train['Ratio_WordCount_Between_Positive_Negative_Reviews'], 2)

        #self.data_loader.data['Weighted_Average_Reviewer_Score'] = ((self.data_loader.data['Reviewer_Score'] *
        #                                                    self.data_loader.data[
        #                                                        'Total_Number_of_Reviews_Reviewer_Has_Given']) +
        #                                                   self.data_loader.data['Log_Reviewer_Score'])

        # Display the dataset after creating interactions
        print('Dataset after creating interactions: \n', self.data_loader.data_train.head(20))

    def count_tags(self, tags):
        array_tags = tags.split(',')
        return len(array_tags)

# %%
feature_analysis = FeatureAnalysisAndGenerator(data_loader)

# Perform Analysis
feature_analysis.perform_feature_analysis()

# Generate new features
feature_analysis.generate_features()

# Perform relevant feature identification
columns = data_loader.data.select_dtypes(include=['number'])
relevant_features = feature_analysis.relevant_feature_identification(len(columns))
relevant_features_mrmr = feature_analysis.select_features_mrmr(len(columns))
# Out:
# PCA
# LDA
# t-SNE
# UMAP
# Mean of Positive Words:  -0.0006107421539625895
# Mean of Negative Words:  0.0001404886058993254
# Dataset after creating interactions:
#                                              Hotel_Address Province_Name  \
# 35593         111 avenue de la Bourdonnais 7th arr 75007         Paris
# 363006                       Lakeside Way Brent  HA9 0BU         London
# 303312         Corso Concordia 1 Milan City Center 20129         Milan
# 263174  97 Cromwell Road Kensington and Chelsea  SW7 4DN         London
# 36193          112 boulevard de S bastopol 3rd arr 75003         Paris
# 234813           7 Gracechurch Street City of   EC3V 0DR         London
# 264256  97 Great Russell Street Bloomsbury Camden  WC1...        London
# 43145                13 15 Gower Street Camden  WC1E 6HE         London
# 163469                       368 370 Green Lanes  N4 1DA         London
# 99627                     20 Rue Jean Rey 15th arr 75015         Paris
# 120188                24 Ludgate Hill City of   EC4M 7DR         London
# 409330   Piazza Luigi di Savoia 20 Central Station 20124         Milan
# 74946              18 Albert Embankment Lambeth  SE1 7TJ         London
# 234935           7 Gracechurch Street City of   EC3V 0DR         London
# 392477                 Opernring 11 01 Innere Stadt 1010        Vienna
# 338500                        Hanger Lane Ealing  W5 3HL         London
# 393865          Overhoeksplein 7 Amsterdam Noord 1031 KS     Amsterdam
# 184262  41 54 Buckingham Gate Westminster Borough  SW1...        London
# 32819   11 13 Bayley Street Bedford Square Camden  WC1...        London
# 378335                                Marina 19 21 08005     Barcelona
#
#           Country_Name Review_Date  Average_Score  \
# 35593           France   8/27/2015       0.734197
# 363006  United Kingdom   3/27/2016       0.734197
# 303312           Italy   2/11/2017       1.099086
# 263174  United Kingdom   4/16/2017      -1.090247
# 36193           France   2/23/2016      -0.178025
# 234813  United Kingdom    6/5/2017      -0.360469
# 264256  United Kingdom    4/2/2016      -0.360469
# 43145   United Kingdom   8/27/2015      -0.178025
# 163469  United Kingdom   7/28/2017      -1.637580
# 99627           France   6/20/2017      -0.725358
# 120188  United Kingdom    1/7/2017       0.004420
# 409330           Italy    4/6/2016       0.551753
# 74946   United Kingdom   6/20/2016      -0.178025
# 234935  United Kingdom  12/31/2016      -0.360469
# 392477         Austria   8/19/2015       0.916642
# 338500  United Kingdom    9/6/2015       0.186864
# 393865     Netherlands   1/18/2017       1.099086
# 184262  United Kingdom  12/21/2016       0.551753
# 32819   United Kingdom   9/27/2016      -0.542913
# 378335           Spain   5/30/2017       0.734197
#
#                                            Hotel_Name  \
# 35593                         H tel de la Bourdonnais
# 363006                          Hilton London Wembley
# 303312                Ch teau Monfort Relais Ch teaux
# 263174            Holiday Inn London Kensington Forum
# 36193   Best Western Premier Marais Grands Boulevards
# 234813                Club Quarters Hotel Gracechurch
# 264256              Radisson Blu Edwardian Kenilworth
# 43145                              Staunton Hotel B B
# 163469              United Lodge Hotel and Apartments
# 99627                Mercure Paris Centre Tour Eiffel
# 120188                  Club Quarters Hotel St Paul s
# 409330                            Starhotels Anderson
# 74946                     Park Plaza London Riverbank
# 234935                Club Quarters Hotel Gracechurch
# 392477                            Das Opernring Hotel
# 338500                                       Hotel 55
# 393865                                 Sir Adam Hotel
# 184262              St James Court A Taj Hotel London
# 32819                                   My Bloomsbury
# 378335                           Hotel Arts Barcelona
#
#               Reviewer_Nationality  \
# 35593              United Kingdom
# 363006             United Kingdom
# 303312                    Romania
# 263174                    Nigeria
# 36193              United Kingdom
# 234813             United Kingdom
# 264256             United Kingdom
# 43145                    Portugal
# 163469             United Kingdom
# 99627                    Bulgaria
# 120188                   Portugal
# 409330   United States of America
# 74946              United Kingdom
# 234935                Netherlands
# 392477                    Belgium
# 338500             United Kingdom
# 393865               Saudi Arabia
# 184262                    Belgium
# 32819              United Kingdom
# 378335                    Belgium
#
#                                           Negative_Review  \
# 35593    Wifi kept failing Room looking out onto inter...
# 363006                                        No Negative
# 303312     Shower presure and thw gyn ahould be improved
# 263174   My room was a bit noisy because of the rail l...
# 36193    We had a very unpleasant stay and we believe ...
# 234813   Not the greatest of views our window looked i...
# 264256   Room was quite noisy due to gap between doubl...
# 43145                                       Broken window
# 163469                 Expected better kitchen facilities
# 99627    Our room was booked for three persons We got ...
# 120188   Some air conditioning noise I believe more th...
# 409330   Bad shower head no English movies no window i...
# 74946    Just simple thing in rooms could have been be...
# 234935   No breakfast facilities and the restaurant wa...
# 392477                                        No Negative
# 338500            Room could have been a little brighter
# 393865                                        No Negative
# 184262      Very small room outdated interior in the room
# 32819    We were in a room which was right on the busy...
# 378335                                   Crowded poolside
#
#         Review_Total_Negative_Word_Counts  \
# 35593                            0.216620
# 363006                          -0.623496
# 303312                          -0.287450
# 263174                          -0.119426
# 36193                           11.675812
# 234813                           1.863249
# 264256                          -0.119426
# 43145                           -0.522682
# 163469                          -0.455473
# 99627                            1.392784
# 120188                          -0.018612
# 409330                          -0.186636
# 74946                            0.418248
# 234935                           0.216620
# 392477                          -0.623496
# 338500                          -0.321054
# 393865                          -0.623496
# 184262                          -0.321054
# 32819                            1.056737
# 378335                          -0.522682
#
#                                           Positive_Review  ...  \
# 35593    Location fabulous Staff friendly and very hel...  ...
# 363006                                     Staff friendly  ...
# 303312   Staff and breakfast We are frequent clients a...  ...
# 263174                           The staff were courteous  ...
# 36193    The price is not bad and it is quite central ...  ...
# 234813   Good location within walking distance of Spit...  ...
# 264256   Breakfast and comfortable bed along with conv...  ...
# 43145                                            Location  ...
# 163469                                        Good garden  ...
# 99627                           Staff were very attentive  ...
# 120188                      The staff was really helpful   ...
# 409330   Helpful front desk interconnecting rooms 110v...  ...
# 74946            The staff were very friendly and helpful  ...
# 234935   The rooms are not too big but comfortable eve...  ...
# 392477   We often visit Vienna but last week was the f...  ...
# 338500   Friendly helpful staff Nespresso coffee and r...  ...
# 393865   Great hospitality from all the staff staring ...  ...
# 184262                    Friendly staff Rooms were clean  ...
# 32819    Bed was comfy and location was fab about 5 mi...  ...
# 378335                              Clean and comfortable  ...
#
#         Ratio_Between_AverageScore_TotalReviews Total_Tags Total_Review_Words  \
# 35593                                  1.097594          5           0.272052
# 363006                                -1.912105          5          -1.301821
# 303312                                 0.733201          5          -0.598896
# 263174                                 1.287656          5          -0.706031
# 36193                                 -4.526624          4          11.501945
# 234813                                 3.894543          5           2.698297
# 264256                                -2.235561          4          -0.063994
# 43145                                 -4.526624          5          -1.246867
# 163469                                -0.492099          5          -1.133797
# 99627                                  1.935406          4           0.806179
# 120188                              -317.636116          5          -0.513498
# 409330                                -2.544368          5          -0.635661
# 74946                                  7.885774          4          -0.030777
# 234935                                 3.894543          5           0.088613
# 392477                                 0.879134          4           3.972053
# 338500                                 4.312496          5           1.339470
# 393865                                 0.733201          5           0.578430
# 184262                                -1.209402          5          -0.861799
# 32819                                 -1.484308          5           1.295608
# 378335                                 1.097594          5          -1.155147
#
#         Ratio_Total_Positive_Words  Ratio_Positive_Words_Mean  \
# 35593                     0.203755                 -90.761862
# 363006                    0.521058                1110.655769
# 303312                    0.520034                 509.946954
# 263174                    0.830848                 960.478565
# 36193                    -0.015116                 284.681148
# 234813                    0.309472               -1367.268096
# 264256                   -0.866203                 -90.761862
# 43145                     0.580803                1185.744371
# 163469                    0.598276                1110.655769
# 99627                    -0.727636                 960.478565
# 120188                    0.963754                 810.301362
# 409330                    0.706391                 735.212760
# 74946                    14.589558                 735.212760
# 234935                   -1.444558                 209.592546
# 392477                    1.156971               -7524.533457
# 338500                    1.239688               -2718.862931
# 393865                    2.077912               -1967.976911
# 184262                    0.627460                 885.389964
# 32819                     0.184370                -391.116270
# 378335                    0.547519                1035.567167
#
#         Ratio_Total_Negative_Words  Ratio_Negative_Words_Mean  \
# 35593                     0.796245                1541.906108
# 363006                    0.478942               -4438.057137
# 303312                    0.479966               -2046.071839
# 263174                    0.169152                -850.079190
# 36193                     1.015116               83108.604762
# 234813                    0.690528               13262.634067
# 264256                    1.866203                -850.079190
# 43145                     0.419197               -3720.461547
# 163469                    0.401724               -3242.064488
# 99627                     1.727636                9913.854650
# 120188                    0.036246                -132.483601
# 409330                    0.293609               -1328.476250
# 74946                   -13.589558                2977.097286
# 234935                    2.444558                1541.906108
# 392477                   -0.156971               -4438.057137
# 338500                   -0.239688               -2285.270369
# 393865                   -1.077912               -4438.057137
# 184262                    0.372540               -2285.270369
# 32819                     0.815630                7521.869352
# 378335                    0.452481               -3720.461547
#
#         Reviewer_Has_Given_Positive_Review  \
# 35593                                    1
# 363006                                   1
# 303312                                   1
# 263174                                   1
# 36193                                    1
# 234813                                   1
# 264256                                   1
# 43145                                    1
# 163469                                   1
# 99627                                    1
# 120188                                   1
# 409330                                   1
# 74946                                    1
# 234935                                   1
# 392477                                   1
# 338500                                   1
# 393865                                   1
# 184262                                   1
# 32819                                    1
# 378335                                   1
#
#         Reviewer_Has_Given_Negative_Review  Square_Ratio_WordCount
# 35593                                    1                0.065482
# 363006                                   1                1.183605
# 303312                                   1                1.173929
# 263174                                   1               24.126269
# 36193                                    1                0.000222
# 234813                                   1                0.200854
# 264256                                   1                0.215438
# 43145                                    1                1.919650
# 163469                                   1                2.217937
# 99627                                    1                0.177388
# 120188                                   1              706.972430
# 409330                                   1                5.788314
# 74946                                    1                1.152587
# 234935                                   1                0.349196
# 392477                                   1               54.325904
# 338500                                   1               26.750570
# 393865                                   1                3.716104
# 184262                                   1                2.836793
# 32819                                    1                0.051097
# 378335                                   1                1.464187
#
# [20 rows x 28 columns]
# 515738 relevant features identified.
# ['Ratio_Total_Positive_Words', 'Ratio_Total_Negative_Words', 'Ratio_WordCount_Between_Positive_Negative_Reviews', 'Square_Ratio_WordCount', 'Total_Review_Words', 'Reviewer_Has_Given_Negative_Review', 'Ratio_Negative_Words_Mean', 'Reviewer_Has_Given_Positive_Review', 'Review_Total_Negative_Word_Counts', 'Review_Total_Positive_Word_Counts', 'Ratio_Positive_Words_Mean', 'lng', 'Average_Score', 'Ratio_Between_AverageScore_TotalReviews', 'lat', 'Total_Tags', 'Review_Count_Per_Hotel_Encoded', 'Reviewer_Expertise_Level_Encoded']
# 100%|██████████| 16/16 [00:05<00:00,  2.80it/s]
# Selected features (mRMR): ['Ratio_Negative_Words_Mean', 'Average_Score', 'Review_Total_Positive_Word_Counts', 'Review_Total_Negative_Word_Counts', 'Ratio_Positive_Words_Mean', 'Ratio_Total_Positive_Words', 'Reviewer_Expertise_Level_Encoded', 'Total_Review_Words', 'lng', 'Review_Count_Per_Hotel_Encoded', 'lat', 'Ratio_WordCount_Between_Positive_Negative_Reviews', 'Ratio_Total_Negative_Words', 'Total_Tags', 'Square_Ratio_WordCount', 'Ratio_Between_AverageScore_TotalReviews']

# %%
# Modified data sample visualization
data_visualization.plot_boxplot()

# %%
# Serialize data_loader object to save a copy of the cleaned data with new features
with open('data_loader_with_new_features.pkl', 'wb') as f:
    pickle.dump(data_loader, f)

# Deserialize data_loader object to restore the cleaned data
with open('data_loader_with_new_features.pkl', 'rb') as f:
    data_loader_loaded = pickle.load(f)
print("Training data shape:", data_loader_loaded.data_train.shape)
print("Training labels shape:", data_loader_loaded.labels_train.shape)
print("Testing data shape:", data_loader_loaded.data_test.shape)
print("Testing labels shape:", data_loader_loaded.labels_test.shape)
# Out:
# Training data shape: (409646, 28)
# Training labels shape: (409646,)
# Testing data shape: (102496, 17)
# Testing labels shape: (102496,)

# %% [markdown]
# ## Statistical Analysis

# %%
import itertools

from scipy.stats import kruskal, f_oneway, ttest_ind


class HypothesisTesting:
    def __init__(self, data_loader):
        self.data_loader = data_loader
        self._data = self.data_loader.data_train.select_dtypes(include=['number'])

    def _perform_anova_test(self, feature):
        """
        Perform an analysis of variance (ANOVA) test for the given feature and multiclass target variable.

        Parameters:
            feature (str): The name of the feature for which the ANOVA test is performed.

        Returns:
            p_value (float): The p-value from the ANOVA test.
            significant (bool): True if the null hypothesis is rejected, indicating a significant relationship.
        """
        # Split data based on the target variable
        data_groups = [self._data.loc[self.data_loader.labels_train == label, feature] for label in
                       self.data_loader.labels_train.unique()]

        # Perform ANOVA test
        f_statistic, p_value = f_oneway(*data_groups)

        # Check significance
        significance = p_value < 0.05

        return p_value, significance

    def _perform_kruskal_test(self, feature):
        """
        Perform a Kruskal-Wallis test for the given feature and multiclass target variable.

        Parameters:
            feature (str): The name of the feature for which the Kruskal-Wallis test is performed.

        Returns:
            p_value (float): The p-value from the Kruskal-Wallis test.
            significant (bool): True if the null hypothesis is rejected, indicating a significant relationship.
        """
        # Split data based on the target variable
        data_groups = [self._data.loc[self.data_loader.labels_train == label, feature] for label in
                       self.data_loader.labels_train.unique()]

        # Perform Kruskal-Wallis test
        h_statistic, p_value = kruskal(*data_groups)

        # Check significance
        significance = p_value < 0.05

        return p_value, significance

    def anova_results(self):
        """
        Prints the ANOVA results
        """

        print("\n\nANOVA results:")
        for feature in self._data.columns:
            p_value, significant = self._perform_anova_test(feature)
            print(f"Feature: {feature}, p-value: {p_value}, Significant: {significant}")

    def kruskal_wallis_results(self):
        """
        Prints the KrSmart Islands Hub: Palestra sobre Aplicação de IA Generativa à Engenhariallis results
        """

        print("\n\nKruskal-Wallis results:")
        for feature in self._data.columns:
            p_value, significant = self._perform_kruskal_test(feature)
            print(f"Feature: {feature}, p-value: {p_value}, Significant: {significant}")

    def t_test_results(self):
        """
        Prints the t-test results in a tabular format.
        """

        print("\n\nT-test results:")
        for feature in self._data.columns:
            print(f"Feature: {feature}")
            for class1, class2 in itertools.combinations(self.data_loader.labels_train.unique(), 2):
                print(f"Class 1: {class1},  Class 2: {class2}")
                data_class1 = self._data.loc[self.data_loader.labels_train == class1, feature]
                data_class2 = self._data.loc[self.data_loader.labels_train == class2, feature]
                t_statistic, p_value = ttest_ind(data_class1, data_class2)
                print('Significant' if p_value < 0.05 else 'Not Significant')

# %%
hypothesis_tester = HypothesisTesting(data_loader)
hypothesis_tester.anova_results()
# hypothesis_tester.kruskal_wallis_results()
hypothesis_tester.t_test_results()
# Out:
# ANOVA results:
# Feature: Average_Score, p-value: 0.0, Significant: True
# Feature: Review_Total_Negative_Word_Counts, p-value: 0.0, Significant: True
# Feature: Review_Total_Positive_Word_Counts, p-value: 0.0, Significant: True
# Feature: lat, p-value: 2.8225327865276425e-93, Significant: True
# Feature: lng, p-value: 4.334474275624052e-110, Significant: True
# Feature: Reviewer_Expertise_Level_Encoded, p-value: 6.386437252512582e-58, Significant: True
# Feature: Review_Count_Per_Hotel_Encoded, p-value: 1.769407728220331e-46, Significant: True
# Feature: Ratio_WordCount_Between_Positive_Negative_Reviews, p-value: 0.0004358407717633542, Significant: True
# Feature: Ratio_Between_AverageScore_TotalReviews, p-value: 0.4908866608740403, Significant: False
# Feature: Total_Tags, p-value: 0.0008349725377601362, Significant: True
# Feature: Total_Review_Words, p-value: 0.0, Significant: True
# Feature: Ratio_Total_Positive_Words, p-value: 1.9584269223341384e-07, Significant: True
# Feature: Ratio_Positive_Words_Mean, p-value: 0.0, Significant: True
# Feature: Ratio_Total_Negative_Words, p-value: 1.9584269223341384e-07, Significant: True
# Feature: Ratio_Negative_Words_Mean, p-value: 0.0, Significant: True
# Feature: Reviewer_Has_Given_Positive_Review, p-value: nan, Significant: False
# Feature: Reviewer_Has_Given_Negative_Review, p-value: nan, Significant: False
# Feature: Square_Ratio_WordCount, p-value: 0.12330156459610803, Significant: False
#
#
# T-test results:
# Feature: Average_Score
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Review_Total_Negative_Word_Counts
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Review_Total_Positive_Word_Counts
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: lat
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: lng
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Reviewer_Expertise_Level_Encoded
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Review_Count_Per_Hotel_Encoded
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: Ratio_WordCount_Between_Positive_Negative_Reviews
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Ratio_Between_AverageScore_TotalReviews
# Class 1: 0,  Class 2: 2
# Not Significant
# Class 1: 0,  Class 2: 1
# Not Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: Total_Tags
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Total_Review_Words
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Ratio_Total_Positive_Words
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Not Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: Ratio_Positive_Words_Mean
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Ratio_Total_Negative_Words
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Not Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: Ratio_Negative_Words_Mean
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Significant
# Class 1: 2,  Class 2: 1
# Significant
# Feature: Reviewer_Has_Given_Positive_Review
# Class 1: 0,  Class 2: 2
# Not Significant
# Class 1: 0,  Class 2: 1
# Not Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: Reviewer_Has_Given_Negative_Review
# Class 1: 0,  Class 2: 2
# Not Significant
# Class 1: 0,  Class 2: 1
# Not Significant
# Class 1: 2,  Class 2: 1
# Not Significant
# Feature: Square_Ratio_WordCount
# Class 1: 0,  Class 2: 2
# Significant
# Class 1: 0,  Class 2: 1
# Not Significant
# Class 1: 2,  Class 2: 1
# Not Significant
